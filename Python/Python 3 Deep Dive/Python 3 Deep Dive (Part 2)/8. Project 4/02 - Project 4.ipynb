# %% [markdown]
# ### GOAL - 1

# %%
from collections import namedtuple
from csv import reader
from datetime import datetime


def generate(file_name: str):
    def create_tuple(iterator):
        header = next(iterator)
        return namedtuple('Data', header)

    def convert(row, mode):
        if mode == 'update_status.csv':
            format = '%Y-%m-%dT%H:%M:%SZ'
            row[1], row[2] = datetime.strptime(row[1], format), datetime.strptime(row[2], format)

        elif mode == 'vehicles.csv':
            row[-1] = int(row[-1])

    with open(file_name) as f:
        data = reader(f, lineterminator='\n')
        Data = create_tuple(data)

        for row in data:
            convert(row, file_name)
            yield Data(*row)

# %%
for i in generate('update_status.csv'):
    print(i)
# Out:
# Data(ssn='100-53-9824', last_updated=datetime.datetime(2017, 10, 7, 0, 14, 42), created=datetime.datetime(2016, 1, 24, 21, 19, 30))
# Data(ssn='101-71-4702', last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57))
# Data(ssn='101-84-0356', last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7))
# Data(ssn='104-22-0928', last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17))
# Data(ssn='104-84-7144', last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57))
# Data(ssn='105-27-5541', last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35))
# Data(ssn='105-85-7486', last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43))
# Data(ssn='105-91-5022', last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3))
# Data(ssn='105-91-7777', last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13))
# Data(ssn='106-35-1938', last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12))
# Data(ssn='106-36-3293', last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36))
# Data(ssn='110-84-3641', last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5))
# Data(ssn='111-35-1034', last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17))
# Data(ssn='114-06-6912', last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3))
# Data(ssn='114-66-0984', last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25))
# Data(ssn='114-74-8701', last_updated=datetime.datetime(2017, 10, 30, 23, 54, 38), created=datetime.datetime(2016, 6, 4, 5, 18, 3))
# Data(ssn='116-10-7235', last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26))
# Data(ssn='116-77-4915', last_updated=datetime.datetime(2017, 11, 21, 14, 25, 11), created=datetime.datetime(2016, 7, 3, 3, 55, 39))
# Data(ssn='117-39-6617', last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17))
# Data(ssn='117-77-9748', last_updated=datetime.datetime(2017, 2, 18, 23, 9, 25), created=datetime.datetime(2016, 2, 2, 15, 41, 42))
# Data(ssn='117-78-6202', last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1))
# Data(ssn='118-21-0357', last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22))
# Data(ssn='118-95-7100', last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28))
# Data(ssn='119-07-8817', last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59))
# Data(ssn='120-33-5535', last_updated=datetime.datetime(2017, 11, 11, 8, 53, 11), created=datetime.datetime(2016, 7, 10, 20, 49))
# Data(ssn='120-98-4054', last_updated=datetime.datetime(2017, 12, 1, 17, 30, 55), created=datetime.datetime(2016, 7, 23, 15, 52, 53))
# Data(ssn='121-98-3948', last_updated=datetime.datetime(2017, 8, 23, 16, 0, 57), created=datetime.datetime(2016, 6, 26, 23, 46, 48))
# Data(ssn='123-05-3229', last_updated=datetime.datetime(2017, 8, 16, 12, 8, 6), created=datetime.datetime(2016, 10, 23, 13, 32, 13))
# Data(ssn='123-62-2832', last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5))
# Data(ssn='123-88-3381', last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36))
# Data(ssn='125-07-9434', last_updated=datetime.datetime(2017, 2, 7, 14, 36, 31), created=datetime.datetime(2016, 7, 8, 17, 46, 23))
# Data(ssn='127-49-2473', last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40))
# Data(ssn='127-52-8001', last_updated=datetime.datetime(2017, 1, 12, 9, 42, 31), created=datetime.datetime(2016, 10, 9, 1, 14, 36))
# Data(ssn='127-68-4232', last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21))
# Data(ssn='127-93-3548', last_updated=datetime.datetime(2017, 9, 10, 6, 24, 19), created=datetime.datetime(2016, 7, 23, 1, 30, 3))
# Data(ssn='128-42-4599', last_updated=datetime.datetime(2017, 1, 29, 20, 31, 15), created=datetime.datetime(2016, 7, 13, 9, 52, 36))
# Data(ssn='128-53-0369', last_updated=datetime.datetime(2017, 8, 10, 21, 18), created=datetime.datetime(2016, 12, 19, 21, 37, 6))
# Data(ssn='128-53-7952', last_updated=datetime.datetime(2017, 8, 31, 16, 42, 23), created=datetime.datetime(2016, 7, 29, 3, 46, 26))
# Data(ssn='128-56-6040', last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56))
# Data(ssn='128-60-4388', last_updated=datetime.datetime(2017, 1, 3, 20, 33, 45), created=datetime.datetime(2016, 3, 18, 11, 18, 14))
# Data(ssn='129-67-0291', last_updated=datetime.datetime(2017, 2, 11, 10, 18, 21), created=datetime.datetime(2016, 12, 12, 5, 1, 34))
# Data(ssn='131-81-4310', last_updated=datetime.datetime(2018, 3, 21, 12, 2, 31), created=datetime.datetime(2016, 2, 3, 23, 26, 27))
# Data(ssn='132-26-3507', last_updated=datetime.datetime(2017, 1, 19, 7, 33, 37), created=datetime.datetime(2016, 5, 20, 1, 41, 54))
# Data(ssn='134-05-0120', last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40))
# Data(ssn='135-86-9625', last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17))
# Data(ssn='137-13-1889', last_updated=datetime.datetime(2017, 12, 24, 9, 44, 10), created=datetime.datetime(2016, 3, 1, 19, 9, 29))
# Data(ssn='138-65-4579', last_updated=datetime.datetime(2017, 4, 17, 16, 30, 2), created=datetime.datetime(2016, 12, 17, 7, 7, 47))
# Data(ssn='138-67-1198', last_updated=datetime.datetime(2018, 3, 4, 8, 14, 31), created=datetime.datetime(2016, 9, 24, 1, 52, 46))
# Data(ssn='138-88-5288', last_updated=datetime.datetime(2017, 2, 24, 15, 47, 36), created=datetime.datetime(2016, 1, 4, 9, 37, 53))
# Data(ssn='139-04-8189', last_updated=datetime.datetime(2017, 2, 16, 21, 23, 10), created=datetime.datetime(2016, 5, 24, 4, 10, 50))
# Data(ssn='139-94-5865', last_updated=datetime.datetime(2017, 8, 19, 16, 22, 52), created=datetime.datetime(2016, 9, 10, 21, 9, 28))
# Data(ssn='139-99-6417', last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20))
# Data(ssn='140-33-9727', last_updated=datetime.datetime(2017, 9, 21, 23, 4, 48), created=datetime.datetime(2016, 1, 27, 9, 2, 26))
# Data(ssn='140-58-8263', last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22))
# Data(ssn='141-15-0543', last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37))
# Data(ssn='141-88-9721', last_updated=datetime.datetime(2018, 1, 24, 20, 0, 4), created=datetime.datetime(2016, 12, 20, 0, 43, 43))
# Data(ssn='142-77-4616', last_updated=datetime.datetime(2017, 7, 16, 15, 12, 37), created=datetime.datetime(2016, 7, 30, 13, 28, 38))
# Data(ssn='142-87-3416', last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54))
# Data(ssn='143-17-4714', last_updated=datetime.datetime(2017, 7, 21, 18, 54, 47), created=datetime.datetime(2016, 2, 9, 6, 10, 21))
# Data(ssn='145-10-8454', last_updated=datetime.datetime(2017, 1, 18, 6, 37, 31), created=datetime.datetime(2016, 4, 25, 21, 45))
# Data(ssn='145-35-5124', last_updated=datetime.datetime(2018, 2, 20, 12, 47, 43), created=datetime.datetime(2016, 10, 3, 5, 18, 6))
# Data(ssn='145-78-3985', last_updated=datetime.datetime(2017, 6, 10, 6, 21, 46), created=datetime.datetime(2016, 9, 23, 15, 35, 52))
# Data(ssn='146-81-3446', last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50))
# Data(ssn='147-33-1463', last_updated=datetime.datetime(2018, 2, 9, 4, 41, 58), created=datetime.datetime(2016, 5, 31, 23, 38, 59))
# Data(ssn='147-47-8577', last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36))
# Data(ssn='147-63-3462', last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52))
# Data(ssn='148-60-7519', last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29))
# Data(ssn='149-18-7272', last_updated=datetime.datetime(2017, 8, 31, 2, 41, 41), created=datetime.datetime(2016, 10, 21, 12, 17, 57))
# Data(ssn='149-45-6482', last_updated=datetime.datetime(2017, 9, 2, 5, 13, 32), created=datetime.datetime(2016, 2, 23, 16, 20, 59))
# Data(ssn='150-64-6357', last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50))
# Data(ssn='150-89-3343', last_updated=datetime.datetime(2017, 6, 4, 1, 39, 16), created=datetime.datetime(2016, 4, 23, 14, 7, 49))
# Data(ssn='151-54-3946', last_updated=datetime.datetime(2018, 2, 8, 11, 16, 12), created=datetime.datetime(2016, 10, 19, 8, 22, 59))
# Data(ssn='151-70-0641', last_updated=datetime.datetime(2017, 2, 13, 21, 31, 15), created=datetime.datetime(2016, 4, 28, 8, 28, 43))
# Data(ssn='151-78-1397', last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10))
# Data(ssn='152-71-3526', last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4))
# Data(ssn='153-67-1309', last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39))
# Data(ssn='154-17-7912', last_updated=datetime.datetime(2017, 4, 19, 22, 8, 24), created=datetime.datetime(2016, 1, 29, 12, 43, 45))
# Data(ssn='156-18-7547', last_updated=datetime.datetime(2017, 9, 10, 22, 58, 31), created=datetime.datetime(2016, 10, 20, 19, 49, 24))
# Data(ssn='156-91-6848', last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32))
# Data(ssn='157-17-9982', last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29))
# Data(ssn='157-38-7090', last_updated=datetime.datetime(2017, 3, 24, 8, 58, 33), created=datetime.datetime(2016, 9, 15, 16, 11, 12))
# Data(ssn='157-51-5269', last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2))
# Data(ssn='161-36-9710', last_updated=datetime.datetime(2017, 7, 3, 6, 26, 41), created=datetime.datetime(2016, 6, 9, 5, 30, 33))
# Data(ssn='161-53-4778', last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55))
# Data(ssn='163-68-8070', last_updated=datetime.datetime(2017, 9, 6, 16, 56, 6), created=datetime.datetime(2016, 10, 23, 1, 47, 51))
# Data(ssn='163-98-1022', last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33))
# Data(ssn='164-11-9849', last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5))
# Data(ssn='166-10-4488', last_updated=datetime.datetime(2017, 8, 14, 16, 48, 43), created=datetime.datetime(2016, 7, 2, 8, 33, 48))
# Data(ssn='167-39-2377', last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1))
# Data(ssn='168-02-5324', last_updated=datetime.datetime(2018, 1, 4, 21, 50, 39), created=datetime.datetime(2016, 1, 29, 15, 31, 40))
# Data(ssn='168-19-8754', last_updated=datetime.datetime(2017, 6, 10, 3, 48, 51), created=datetime.datetime(2016, 9, 27, 15, 4, 24))
# Data(ssn='168-81-0838', last_updated=datetime.datetime(2017, 2, 11, 14, 12, 16), created=datetime.datetime(2016, 9, 19, 20, 5, 7))
# Data(ssn='168-89-6661', last_updated=datetime.datetime(2017, 7, 17, 2, 59, 15), created=datetime.datetime(2016, 4, 30, 9, 17, 39))
# Data(ssn='170-65-3388', last_updated=datetime.datetime(2017, 3, 5, 0, 46, 26), created=datetime.datetime(2016, 6, 15, 5, 37, 27))
# Data(ssn='171-27-7781', last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37))
# Data(ssn='172-23-7739', last_updated=datetime.datetime(2018, 3, 2, 23, 30, 36), created=datetime.datetime(2016, 5, 12, 16, 1, 48))
# Data(ssn='172-77-4263', last_updated=datetime.datetime(2017, 10, 11, 13, 32, 41), created=datetime.datetime(2016, 9, 10, 9, 18, 50))
# Data(ssn='172-89-7546', last_updated=datetime.datetime(2017, 1, 25, 2, 11, 6), created=datetime.datetime(2016, 7, 24, 12, 57, 57))
# Data(ssn='173-99-7372', last_updated=datetime.datetime(2018, 3, 3, 15, 18, 26), created=datetime.datetime(2016, 10, 26, 15, 24, 37))
# Data(ssn='174-13-2047', last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59))
# Data(ssn='174-35-3812', last_updated=datetime.datetime(2017, 1, 25, 11, 34, 25), created=datetime.datetime(2016, 5, 14, 4, 55, 35))
# Data(ssn='174-51-9992', last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25))
# Data(ssn='174-87-2537', last_updated=datetime.datetime(2017, 9, 30, 14, 38, 36), created=datetime.datetime(2016, 8, 1, 11, 19, 25))
# Data(ssn='176-82-1359', last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42))
# Data(ssn='176-99-5851', last_updated=datetime.datetime(2017, 4, 1, 20, 14, 53), created=datetime.datetime(2016, 12, 3, 15, 8, 4))
# Data(ssn='179-88-2790', last_updated=datetime.datetime(2017, 3, 23, 1, 30, 12), created=datetime.datetime(2016, 3, 6, 13, 15, 20))
# Data(ssn='181-07-4434', last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19))
# Data(ssn='181-28-8337', last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49))
# Data(ssn='181-88-6077', last_updated=datetime.datetime(2017, 8, 16, 21, 35, 50), created=datetime.datetime(2016, 9, 15, 10, 22, 56))
# Data(ssn='182-15-5082', last_updated=datetime.datetime(2017, 10, 2, 6, 22, 27), created=datetime.datetime(2016, 10, 16, 12, 16, 53))
# Data(ssn='182-81-4541', last_updated=datetime.datetime(2017, 7, 5, 10, 19, 41), created=datetime.datetime(2016, 7, 23, 3, 16, 13))
# Data(ssn='183-10-5024', last_updated=datetime.datetime(2017, 11, 3, 0, 36, 20), created=datetime.datetime(2016, 9, 8, 5, 10, 46))
# Data(ssn='184-60-6243', last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46))
# Data(ssn='184-84-1003', last_updated=datetime.datetime(2017, 10, 15, 21, 11, 17), created=datetime.datetime(2016, 11, 17, 18, 52, 56))
# Data(ssn='184-92-3560', last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30))
# Data(ssn='184-94-5241', last_updated=datetime.datetime(2017, 3, 28, 16, 56, 35), created=datetime.datetime(2016, 6, 3, 5, 38, 20))
# Data(ssn='185-50-0434', last_updated=datetime.datetime(2017, 2, 19, 15, 12, 50), created=datetime.datetime(2016, 10, 24, 14, 3, 4))
# Data(ssn='185-84-9868', last_updated=datetime.datetime(2017, 7, 1, 13, 56, 28), created=datetime.datetime(2016, 8, 8, 8, 4, 45))
# Data(ssn='186-65-7773', last_updated=datetime.datetime(2017, 6, 9, 12, 34, 32), created=datetime.datetime(2016, 9, 17, 22, 55, 15))
# Data(ssn='188-20-9317', last_updated=datetime.datetime(2017, 12, 26, 5, 29, 23), created=datetime.datetime(2016, 6, 5, 4, 26, 52))
# Data(ssn='188-40-4336', last_updated=datetime.datetime(2017, 12, 27, 3, 41, 46), created=datetime.datetime(2016, 6, 30, 2, 48, 10))
# Data(ssn='189-26-5696', last_updated=datetime.datetime(2017, 8, 8, 19, 29, 59), created=datetime.datetime(2016, 9, 9, 19, 38, 18))
# Data(ssn='189-49-1458', last_updated=datetime.datetime(2017, 2, 12, 16, 15, 44), created=datetime.datetime(2016, 6, 21, 4, 10, 57))
# Data(ssn='190-05-6987', last_updated=datetime.datetime(2017, 6, 6, 20, 51, 23), created=datetime.datetime(2016, 2, 17, 12, 0, 16))
# Data(ssn='190-53-4517', last_updated=datetime.datetime(2018, 2, 12, 20, 26, 30), created=datetime.datetime(2016, 4, 15, 16, 42, 18))
# Data(ssn='191-15-3194', last_updated=datetime.datetime(2017, 7, 27, 9, 14, 42), created=datetime.datetime(2016, 5, 23, 13, 52, 39))
# Data(ssn='192-54-0695', last_updated=datetime.datetime(2017, 3, 18, 6, 5, 59), created=datetime.datetime(2016, 11, 16, 1, 58, 55))
# Data(ssn='192-67-3201', last_updated=datetime.datetime(2017, 1, 19, 20, 59, 49), created=datetime.datetime(2016, 6, 13, 1, 23, 53))
# Data(ssn='194-76-5816', last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14))
# Data(ssn='195-23-5731', last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3))
# Data(ssn='196-69-3796', last_updated=datetime.datetime(2017, 1, 23, 2, 41, 20), created=datetime.datetime(2016, 8, 1, 21, 34, 6))
# Data(ssn='198-70-6443', last_updated=datetime.datetime(2017, 2, 13, 7, 16, 31), created=datetime.datetime(2016, 1, 22, 5, 10, 14))
# Data(ssn='199-45-0804', last_updated=datetime.datetime(2017, 6, 23, 12, 59, 20), created=datetime.datetime(2016, 11, 7, 0, 25, 12))
# Data(ssn='199-54-4639', last_updated=datetime.datetime(2018, 2, 23, 10, 14, 54), created=datetime.datetime(2016, 4, 5, 5, 11, 13))
# Data(ssn='200-81-7151', last_updated=datetime.datetime(2017, 11, 19, 13, 58, 42), created=datetime.datetime(2016, 7, 31, 19, 2, 12))
# Data(ssn='201-53-1249', last_updated=datetime.datetime(2017, 11, 25, 14, 19, 29), created=datetime.datetime(2016, 10, 7, 18, 42, 12))
# Data(ssn='202-84-1146', last_updated=datetime.datetime(2017, 4, 1, 22, 1, 53), created=datetime.datetime(2016, 7, 21, 8, 10, 25))
# Data(ssn='203-35-7648', last_updated=datetime.datetime(2017, 12, 1, 14, 42, 14), created=datetime.datetime(2016, 8, 2, 14, 24, 12))
# Data(ssn='205-69-7375', last_updated=datetime.datetime(2018, 2, 27, 13, 25, 24), created=datetime.datetime(2016, 5, 19, 12, 10, 37))
# Data(ssn='205-87-2423', last_updated=datetime.datetime(2018, 1, 1, 8, 17, 27), created=datetime.datetime(2016, 2, 16, 23, 45, 38))
# Data(ssn='206-28-6674', last_updated=datetime.datetime(2017, 10, 14, 6, 32, 53), created=datetime.datetime(2016, 8, 1, 8, 2, 52))
# Data(ssn='206-83-8848', last_updated=datetime.datetime(2017, 11, 8, 14, 57, 17), created=datetime.datetime(2016, 4, 11, 17, 40, 42))
# Data(ssn='208-74-2166', last_updated=datetime.datetime(2017, 1, 24, 9, 46, 24), created=datetime.datetime(2016, 2, 28, 8, 58, 53))
# Data(ssn='208-80-5879', last_updated=datetime.datetime(2017, 10, 16, 21, 39, 4), created=datetime.datetime(2016, 3, 31, 17, 4, 29))
# Data(ssn='209-50-8146', last_updated=datetime.datetime(2018, 3, 13, 17, 52, 16), created=datetime.datetime(2016, 4, 10, 7, 14, 25))
# Data(ssn='209-58-4708', last_updated=datetime.datetime(2018, 2, 8, 21, 22, 2), created=datetime.datetime(2016, 6, 17, 9, 21, 14))
# Data(ssn='210-91-4729', last_updated=datetime.datetime(2017, 7, 11, 8, 17, 40), created=datetime.datetime(2016, 12, 4, 0, 41, 8))
# Data(ssn='211-04-1734', last_updated=datetime.datetime(2018, 3, 11, 20, 29, 12), created=datetime.datetime(2016, 8, 30, 15, 59, 14))
# Data(ssn='211-13-5247', last_updated=datetime.datetime(2018, 2, 22, 16, 37, 12), created=datetime.datetime(2016, 12, 20, 3, 14, 56))
# Data(ssn='211-15-5182', last_updated=datetime.datetime(2017, 4, 15, 16, 17, 42), created=datetime.datetime(2016, 3, 17, 19, 14, 56))
# Data(ssn='211-19-6826', last_updated=datetime.datetime(2018, 2, 12, 4, 33, 14), created=datetime.datetime(2016, 8, 25, 22, 0, 15))
# Data(ssn='212-40-0215', last_updated=datetime.datetime(2017, 2, 1, 18, 11, 47), created=datetime.datetime(2016, 1, 6, 22, 31, 22))
# Data(ssn='212-41-1496', last_updated=datetime.datetime(2017, 7, 7, 20, 29, 9), created=datetime.datetime(2016, 10, 27, 12, 47, 10))
# Data(ssn='213-28-1395', last_updated=datetime.datetime(2017, 6, 4, 4, 51, 16), created=datetime.datetime(2016, 6, 11, 0, 6, 58))
# Data(ssn='214-29-1189', last_updated=datetime.datetime(2018, 2, 16, 8, 10, 36), created=datetime.datetime(2016, 6, 2, 0, 48, 2))
# Data(ssn='214-96-8581', last_updated=datetime.datetime(2017, 4, 30, 7, 25, 59), created=datetime.datetime(2016, 8, 18, 0, 21, 7))
# Data(ssn='214-99-7584', last_updated=datetime.datetime(2018, 2, 22, 11, 32, 50), created=datetime.datetime(2016, 7, 14, 3, 30, 15))
# Data(ssn='216-89-3812', last_updated=datetime.datetime(2018, 3, 11, 20, 2, 23), created=datetime.datetime(2016, 7, 28, 7, 3, 44))
# Data(ssn='216-97-3104', last_updated=datetime.datetime(2017, 2, 10, 18, 28, 9), created=datetime.datetime(2016, 9, 6, 8, 20, 10))
# Data(ssn='217-71-3922', last_updated=datetime.datetime(2017, 11, 11, 19, 44, 46), created=datetime.datetime(2016, 3, 4, 12, 33, 51))
# Data(ssn='217-81-5416', last_updated=datetime.datetime(2017, 12, 27, 18, 15, 59), created=datetime.datetime(2016, 11, 20, 2, 39, 48))
# Data(ssn='218-14-4448', last_updated=datetime.datetime(2017, 7, 22, 9, 16, 18), created=datetime.datetime(2016, 6, 29, 6, 28, 37))
# Data(ssn='218-25-9873', last_updated=datetime.datetime(2017, 5, 11, 20, 22, 10), created=datetime.datetime(2016, 3, 11, 12, 58, 1))
# Data(ssn='218-31-1615', last_updated=datetime.datetime(2017, 8, 3, 8, 57, 27), created=datetime.datetime(2016, 5, 14, 20, 4, 1))
# Data(ssn='218-49-7300', last_updated=datetime.datetime(2017, 12, 22, 19, 46, 19), created=datetime.datetime(2016, 9, 17, 5, 14, 16))
# Data(ssn='220-16-0476', last_updated=datetime.datetime(2017, 3, 9, 16, 48, 29), created=datetime.datetime(2016, 7, 4, 6, 40, 49))
# Data(ssn='220-38-0208', last_updated=datetime.datetime(2017, 11, 10, 15, 6, 25), created=datetime.datetime(2016, 10, 28, 19, 34, 21))
# Data(ssn='222-39-8571', last_updated=datetime.datetime(2017, 2, 3, 23, 45, 13), created=datetime.datetime(2016, 10, 4, 0, 52, 58))
# Data(ssn='223-67-9203', last_updated=datetime.datetime(2017, 8, 4, 12, 57, 4), created=datetime.datetime(2016, 12, 2, 13, 29, 54))
# Data(ssn='223-98-0846', last_updated=datetime.datetime(2017, 3, 29, 16, 7, 6), created=datetime.datetime(2016, 6, 29, 2, 47, 31))
# Data(ssn='224-12-3436', last_updated=datetime.datetime(2018, 1, 9, 23, 34, 10), created=datetime.datetime(2016, 10, 6, 12, 21, 57))
# Data(ssn='224-30-9267', last_updated=datetime.datetime(2017, 12, 17, 11, 57, 56), created=datetime.datetime(2016, 11, 13, 20, 27, 10))
# Data(ssn='224-54-6919', last_updated=datetime.datetime(2017, 2, 11, 17, 13, 36), created=datetime.datetime(2016, 1, 30, 9, 3, 19))
# Data(ssn='224-84-2271', last_updated=datetime.datetime(2018, 1, 23, 21, 14, 49), created=datetime.datetime(2016, 6, 14, 13, 25, 45))
# Data(ssn='224-99-0668', last_updated=datetime.datetime(2017, 4, 1, 17, 51, 23), created=datetime.datetime(2016, 1, 3, 6, 43, 7))
# Data(ssn='225-08-5789', last_updated=datetime.datetime(2017, 8, 5, 11, 29, 59), created=datetime.datetime(2016, 4, 1, 16, 56, 12))
# Data(ssn='225-64-2735', last_updated=datetime.datetime(2017, 12, 24, 21, 44, 27), created=datetime.datetime(2016, 7, 16, 23, 1, 13))
# Data(ssn='226-76-4452', last_updated=datetime.datetime(2017, 7, 8, 12, 13, 2), created=datetime.datetime(2016, 3, 18, 0, 10, 46))
# Data(ssn='227-72-7247', last_updated=datetime.datetime(2017, 12, 4, 7, 32, 34), created=datetime.datetime(2016, 8, 3, 15, 37, 18))
# Data(ssn='228-16-7922', last_updated=datetime.datetime(2017, 8, 7, 2, 28, 53), created=datetime.datetime(2016, 10, 8, 19, 36, 43))
# Data(ssn='228-55-2042', last_updated=datetime.datetime(2017, 1, 17, 20, 5, 40), created=datetime.datetime(2016, 3, 8, 17, 42, 55))
# Data(ssn='228-90-5077', last_updated=datetime.datetime(2018, 2, 26, 10, 52, 3), created=datetime.datetime(2016, 5, 6, 9, 54, 1))
# Data(ssn='229-44-9909', last_updated=datetime.datetime(2017, 6, 21, 5, 51, 8), created=datetime.datetime(2016, 12, 29, 8, 27, 3))
# Data(ssn='230-09-1794', last_updated=datetime.datetime(2018, 1, 27, 21, 49, 27), created=datetime.datetime(2016, 10, 22, 14, 54, 5))
# Data(ssn='230-48-0684', last_updated=datetime.datetime(2018, 3, 26, 6, 15, 57), created=datetime.datetime(2016, 12, 29, 6, 0, 3))
# Data(ssn='230-99-1485', last_updated=datetime.datetime(2017, 8, 10, 19, 34, 42), created=datetime.datetime(2016, 9, 19, 22, 26, 22))
# Data(ssn='231-66-9264', last_updated=datetime.datetime(2017, 4, 7, 22, 50, 50), created=datetime.datetime(2016, 6, 1, 8, 10, 38))
# Data(ssn='232-18-5397', last_updated=datetime.datetime(2017, 9, 23, 2, 16, 56), created=datetime.datetime(2016, 2, 20, 4, 33, 2))
# Data(ssn='233-27-2377', last_updated=datetime.datetime(2018, 1, 31, 9, 38, 49), created=datetime.datetime(2016, 2, 13, 21, 32, 41))
# Data(ssn='235-10-3518', last_updated=datetime.datetime(2017, 8, 8, 16, 14, 22), created=datetime.datetime(2016, 8, 9, 12, 36, 49))
# Data(ssn='236-31-8333', last_updated=datetime.datetime(2017, 1, 3, 13, 2, 1), created=datetime.datetime(2016, 1, 16, 12, 51, 28))
# Data(ssn='236-37-2567', last_updated=datetime.datetime(2017, 9, 1, 17, 59, 5), created=datetime.datetime(2016, 3, 1, 16, 19, 30))
# Data(ssn='237-48-6737', last_updated=datetime.datetime(2017, 1, 22, 14, 20, 20), created=datetime.datetime(2016, 10, 19, 13, 28, 28))
# Data(ssn='237-80-7039', last_updated=datetime.datetime(2017, 6, 20, 5, 20, 53), created=datetime.datetime(2016, 9, 5, 21, 2, 3))
# Data(ssn='238-13-8034', last_updated=datetime.datetime(2017, 5, 9, 1, 16, 29), created=datetime.datetime(2016, 2, 17, 14, 44, 51))
# Data(ssn='238-39-9999', last_updated=datetime.datetime(2017, 12, 17, 18, 36, 23), created=datetime.datetime(2016, 10, 20, 4, 17, 23))
# Data(ssn='239-09-9133', last_updated=datetime.datetime(2018, 1, 28, 2, 19, 9), created=datetime.datetime(2016, 8, 4, 10, 29, 19))
# Data(ssn='239-37-4122', last_updated=datetime.datetime(2017, 9, 20, 20, 47, 44), created=datetime.datetime(2016, 3, 5, 9, 16, 37))
# Data(ssn='240-08-8805', last_updated=datetime.datetime(2017, 2, 10, 12, 14, 31), created=datetime.datetime(2016, 8, 15, 20, 52, 10))
# Data(ssn='240-32-8915', last_updated=datetime.datetime(2017, 4, 18, 14, 30, 22), created=datetime.datetime(2016, 2, 25, 19, 4, 17))
# Data(ssn='240-67-6258', last_updated=datetime.datetime(2017, 10, 17, 17, 8, 33), created=datetime.datetime(2016, 5, 24, 9, 11, 51))
# Data(ssn='242-22-9624', last_updated=datetime.datetime(2017, 3, 31, 4, 48, 46), created=datetime.datetime(2016, 11, 15, 23, 9, 12))
# Data(ssn='243-37-9496', last_updated=datetime.datetime(2017, 5, 5, 6, 46, 9), created=datetime.datetime(2016, 9, 27, 0, 48, 56))
# Data(ssn='243-44-4611', last_updated=datetime.datetime(2017, 8, 28, 4, 20, 56), created=datetime.datetime(2016, 7, 29, 20, 21, 30))
# Data(ssn='244-34-2210', last_updated=datetime.datetime(2017, 12, 30, 9, 16, 58), created=datetime.datetime(2016, 11, 12, 19, 43, 59))
# Data(ssn='244-52-7593', last_updated=datetime.datetime(2017, 12, 19, 22, 53, 28), created=datetime.datetime(2016, 9, 24, 23, 2, 28))
# Data(ssn='244-79-3004', last_updated=datetime.datetime(2017, 9, 8, 9, 13, 42), created=datetime.datetime(2016, 8, 17, 18, 53, 29))
# Data(ssn='244-81-0671', last_updated=datetime.datetime(2017, 6, 23, 11, 56, 59), created=datetime.datetime(2016, 9, 8, 8, 33, 21))
# Data(ssn='245-60-5880', last_updated=datetime.datetime(2017, 4, 5, 20, 44, 3), created=datetime.datetime(2016, 2, 6, 3, 16, 59))
# Data(ssn='245-77-4110', last_updated=datetime.datetime(2017, 3, 6, 5, 50, 56), created=datetime.datetime(2016, 8, 22, 4, 57, 23))
# Data(ssn='247-08-9326', last_updated=datetime.datetime(2017, 10, 20, 3, 18, 53), created=datetime.datetime(2016, 9, 15, 4, 25, 48))
# Data(ssn='247-86-5288', last_updated=datetime.datetime(2017, 8, 7, 13, 12, 28), created=datetime.datetime(2016, 1, 13, 5, 54, 25))
# Data(ssn='248-07-9757', last_updated=datetime.datetime(2018, 2, 25, 14, 10, 22), created=datetime.datetime(2016, 1, 25, 22, 14, 58))
# Data(ssn='248-23-0150', last_updated=datetime.datetime(2017, 3, 6, 2, 7, 51), created=datetime.datetime(2016, 8, 27, 12, 22, 11))
# Data(ssn='249-19-5514', last_updated=datetime.datetime(2017, 11, 18, 7, 3, 15), created=datetime.datetime(2016, 7, 23, 19, 17, 37))
# Data(ssn='253-61-8401', last_updated=datetime.datetime(2018, 1, 22, 4, 2, 1), created=datetime.datetime(2016, 10, 2, 2, 18, 55))
# Data(ssn='254-10-6071', last_updated=datetime.datetime(2017, 7, 27, 8, 15, 23), created=datetime.datetime(2016, 4, 1, 23, 46, 56))
# Data(ssn='254-92-9669', last_updated=datetime.datetime(2017, 6, 27, 8, 31, 24), created=datetime.datetime(2016, 4, 8, 21, 14, 39))
# Data(ssn='255-81-0958', last_updated=datetime.datetime(2017, 1, 14, 1, 34, 12), created=datetime.datetime(2016, 9, 9, 15, 46, 19))
# Data(ssn='256-54-7507', last_updated=datetime.datetime(2017, 3, 6, 4, 47, 24), created=datetime.datetime(2016, 4, 5, 12, 48, 34))
# Data(ssn='256-57-0666', last_updated=datetime.datetime(2017, 10, 8, 2, 5, 59), created=datetime.datetime(2016, 9, 30, 19, 42, 52))
# Data(ssn='257-12-6834', last_updated=datetime.datetime(2018, 3, 27, 21, 18, 39), created=datetime.datetime(2016, 11, 24, 9, 46, 5))
# Data(ssn='257-59-8603', last_updated=datetime.datetime(2017, 4, 12, 7, 13, 58), created=datetime.datetime(2016, 6, 7, 14, 41, 15))
# Data(ssn='257-77-3669', last_updated=datetime.datetime(2017, 7, 29, 13, 33, 21), created=datetime.datetime(2016, 11, 30, 14, 43, 14))
# Data(ssn='258-22-6416', last_updated=datetime.datetime(2017, 4, 28, 1, 14, 30), created=datetime.datetime(2016, 5, 7, 18, 26, 17))
# Data(ssn='259-38-5920', last_updated=datetime.datetime(2017, 7, 23, 21, 2, 37), created=datetime.datetime(2016, 10, 4, 9, 8, 54))
# Data(ssn='261-14-9490', last_updated=datetime.datetime(2017, 1, 26, 12, 19, 19), created=datetime.datetime(2016, 4, 23, 9, 0, 56))
# Data(ssn='262-09-2144', last_updated=datetime.datetime(2018, 1, 7, 8, 54, 1), created=datetime.datetime(2016, 7, 26, 12, 0, 47))
# Data(ssn='262-46-7573', last_updated=datetime.datetime(2017, 11, 3, 2, 47, 17), created=datetime.datetime(2016, 8, 22, 17, 8, 16))
# Data(ssn='262-55-4066', last_updated=datetime.datetime(2017, 6, 3, 10, 15, 39), created=datetime.datetime(2016, 12, 20, 9, 49, 37))
# Data(ssn='262-66-7030', last_updated=datetime.datetime(2018, 1, 23, 23, 44, 35), created=datetime.datetime(2016, 3, 22, 3, 8, 3))
# Data(ssn='264-39-3910', last_updated=datetime.datetime(2017, 10, 5, 3, 39, 11), created=datetime.datetime(2016, 8, 12, 8, 53, 33))
# Data(ssn='266-86-9980', last_updated=datetime.datetime(2018, 2, 19, 20, 34, 9), created=datetime.datetime(2016, 7, 7, 5, 6, 40))
# Data(ssn='267-75-6383', last_updated=datetime.datetime(2017, 1, 18, 3, 2, 58), created=datetime.datetime(2016, 5, 12, 18, 5, 24))
# Data(ssn='269-01-2640', last_updated=datetime.datetime(2017, 11, 23, 14, 20, 56), created=datetime.datetime(2016, 9, 9, 8, 12, 54))
# Data(ssn='271-04-0134', last_updated=datetime.datetime(2017, 5, 14, 7, 18, 59), created=datetime.datetime(2016, 8, 2, 17, 22, 46))
# Data(ssn='271-81-9938', last_updated=datetime.datetime(2017, 1, 29, 1, 31, 37), created=datetime.datetime(2016, 8, 16, 6, 47, 48))
# Data(ssn='271-93-3051', last_updated=datetime.datetime(2017, 2, 18, 16, 44, 2), created=datetime.datetime(2016, 6, 8, 11, 36, 44))
# Data(ssn='272-50-7309', last_updated=datetime.datetime(2017, 3, 20, 5, 38, 57), created=datetime.datetime(2016, 2, 24, 17, 32, 46))
# Data(ssn='272-81-7979', last_updated=datetime.datetime(2018, 1, 14, 21, 6, 5), created=datetime.datetime(2016, 6, 4, 3, 9, 24))
# Data(ssn='273-49-8218', last_updated=datetime.datetime(2017, 9, 9, 5, 26, 20), created=datetime.datetime(2016, 9, 27, 0, 5, 15))
# Data(ssn='274-50-3806', last_updated=datetime.datetime(2017, 5, 13, 5, 8, 51), created=datetime.datetime(2016, 6, 3, 3, 7, 43))
# Data(ssn='274-76-9883', last_updated=datetime.datetime(2017, 10, 9, 4, 11, 3), created=datetime.datetime(2016, 12, 22, 11, 44, 48))
# Data(ssn='276-05-2973', last_updated=datetime.datetime(2017, 11, 3, 5, 30, 21), created=datetime.datetime(2016, 3, 21, 11, 51, 10))
# Data(ssn='278-55-5842', last_updated=datetime.datetime(2018, 1, 2, 5, 17, 17), created=datetime.datetime(2016, 5, 1, 8, 36, 52))
# Data(ssn='278-64-4853', last_updated=datetime.datetime(2017, 12, 17, 20, 59, 8), created=datetime.datetime(2016, 7, 10, 13, 32, 27))
# Data(ssn='279-12-7167', last_updated=datetime.datetime(2017, 3, 17, 17, 36, 17), created=datetime.datetime(2016, 8, 6, 1, 23, 43))
# Data(ssn='279-40-5540', last_updated=datetime.datetime(2017, 8, 25, 15, 27, 27), created=datetime.datetime(2016, 7, 27, 23, 55, 42))
# Data(ssn='279-49-5682', last_updated=datetime.datetime(2017, 11, 27, 7, 44, 58), created=datetime.datetime(2016, 11, 9, 19, 42, 41))
# Data(ssn='280-53-7447', last_updated=datetime.datetime(2017, 5, 12, 7, 46, 5), created=datetime.datetime(2016, 2, 16, 0, 15, 21))
# Data(ssn='280-98-4410', last_updated=datetime.datetime(2017, 8, 10, 14, 59, 8), created=datetime.datetime(2016, 10, 11, 7, 49, 19))
# Data(ssn='281-23-3458', last_updated=datetime.datetime(2017, 6, 21, 9, 17, 37), created=datetime.datetime(2016, 2, 18, 5, 27))
# Data(ssn='282-83-9206', last_updated=datetime.datetime(2017, 11, 30, 2, 29, 14), created=datetime.datetime(2016, 10, 11, 1, 11, 32))
# Data(ssn='283-04-6835', last_updated=datetime.datetime(2017, 5, 29, 2, 43, 42), created=datetime.datetime(2016, 5, 17, 15, 7, 44))
# Data(ssn='286-26-4004', last_updated=datetime.datetime(2017, 7, 6, 13, 34, 13), created=datetime.datetime(2016, 7, 15, 11, 24, 21))
# Data(ssn='287-57-9688', last_updated=datetime.datetime(2017, 3, 25, 16, 51, 30), created=datetime.datetime(2016, 4, 4, 10, 16, 41))
# Data(ssn='287-66-2660', last_updated=datetime.datetime(2018, 1, 8, 5, 9, 53), created=datetime.datetime(2016, 1, 3, 15, 12, 3))
# Data(ssn='288-54-7233', last_updated=datetime.datetime(2017, 4, 9, 3, 49, 3), created=datetime.datetime(2016, 1, 13, 21, 17, 3))
# Data(ssn='288-87-6462', last_updated=datetime.datetime(2017, 4, 28, 5, 43, 4), created=datetime.datetime(2016, 6, 11, 6, 48, 8))
# Data(ssn='289-03-9882', last_updated=datetime.datetime(2017, 6, 29, 11, 35, 32), created=datetime.datetime(2016, 4, 30, 10, 2, 41))
# Data(ssn='289-09-8686', last_updated=datetime.datetime(2017, 9, 15, 1, 56, 26), created=datetime.datetime(2016, 5, 18, 1, 46, 32))
# Data(ssn='290-25-7300', last_updated=datetime.datetime(2017, 4, 13, 6, 2, 34), created=datetime.datetime(2016, 11, 25, 16, 46, 39))
# Data(ssn='290-82-4968', last_updated=datetime.datetime(2017, 7, 3, 20, 17, 20), created=datetime.datetime(2016, 3, 11, 4, 18, 51))
# Data(ssn='293-54-3694', last_updated=datetime.datetime(2017, 7, 10, 11, 18, 54), created=datetime.datetime(2016, 8, 18, 20, 59, 31))
# Data(ssn='294-27-9936', last_updated=datetime.datetime(2018, 2, 7, 23, 28, 14), created=datetime.datetime(2016, 9, 14, 4, 10, 51))
# Data(ssn='294-53-1911', last_updated=datetime.datetime(2018, 3, 8, 15, 24, 15), created=datetime.datetime(2016, 7, 22, 21, 42, 17))
# Data(ssn='295-63-7693', last_updated=datetime.datetime(2017, 2, 28, 11, 27, 31), created=datetime.datetime(2016, 1, 7, 4, 36, 56))
# Data(ssn='296-32-7910', last_updated=datetime.datetime(2017, 5, 8, 14, 27, 35), created=datetime.datetime(2016, 11, 18, 18, 55, 41))
# Data(ssn='296-88-0097', last_updated=datetime.datetime(2017, 6, 28, 19, 41, 12), created=datetime.datetime(2016, 1, 1, 23, 18, 36))
# Data(ssn='296-90-4908', last_updated=datetime.datetime(2017, 5, 8, 13, 53, 40), created=datetime.datetime(2016, 4, 12, 0, 23, 9))
# Data(ssn='297-63-1154', last_updated=datetime.datetime(2018, 1, 18, 23, 20, 37), created=datetime.datetime(2016, 3, 3, 14, 10, 1))
# Data(ssn='298-06-3497', last_updated=datetime.datetime(2017, 10, 24, 4, 25, 1), created=datetime.datetime(2016, 11, 6, 17, 11, 40))
# Data(ssn='298-69-9168', last_updated=datetime.datetime(2017, 10, 11, 23, 18, 49), created=datetime.datetime(2016, 10, 30, 0, 58, 22))
# Data(ssn='298-70-6018', last_updated=datetime.datetime(2018, 2, 12, 10, 5, 39), created=datetime.datetime(2016, 3, 28, 9, 53, 54))
# Data(ssn='298-79-7640', last_updated=datetime.datetime(2017, 11, 27, 0, 8, 54), created=datetime.datetime(2016, 11, 8, 8, 9, 5))
# Data(ssn='299-03-6911', last_updated=datetime.datetime(2017, 1, 19, 3, 33, 50), created=datetime.datetime(2016, 3, 7, 15, 33, 32))
# Data(ssn='299-38-0483', last_updated=datetime.datetime(2017, 9, 20, 16, 34, 47), created=datetime.datetime(2016, 6, 1, 9, 6, 19))
# Data(ssn='299-77-1060', last_updated=datetime.datetime(2017, 3, 13, 1, 59, 12), created=datetime.datetime(2016, 11, 1, 3, 27, 51))
# Data(ssn='300-59-3610', last_updated=datetime.datetime(2017, 8, 21, 10, 1, 31), created=datetime.datetime(2016, 6, 23, 4, 44, 22))
# Data(ssn='300-76-8770', last_updated=datetime.datetime(2017, 8, 21, 0, 3, 14), created=datetime.datetime(2016, 3, 13, 15, 45, 7))
# Data(ssn='300-80-7209', last_updated=datetime.datetime(2017, 11, 13, 1, 58, 56), created=datetime.datetime(2016, 11, 8, 3, 17, 4))
# Data(ssn='301-26-4306', last_updated=datetime.datetime(2017, 6, 20, 20, 49, 12), created=datetime.datetime(2016, 1, 25, 11, 1, 19))
# Data(ssn='301-51-0522', last_updated=datetime.datetime(2017, 7, 3, 16, 20, 32), created=datetime.datetime(2016, 7, 28, 2, 33, 50))
# Data(ssn='302-64-4858', last_updated=datetime.datetime(2018, 2, 22, 14, 59, 17), created=datetime.datetime(2016, 5, 4, 18, 49, 4))
# Data(ssn='304-48-4312', last_updated=datetime.datetime(2017, 6, 8, 17, 56, 34), created=datetime.datetime(2016, 7, 23, 15, 40, 8))
# Data(ssn='305-07-1498', last_updated=datetime.datetime(2017, 6, 18, 5, 38, 20), created=datetime.datetime(2016, 1, 31, 18, 6, 58))
# Data(ssn='306-23-2423', last_updated=datetime.datetime(2018, 2, 11, 1, 37, 8), created=datetime.datetime(2016, 9, 12, 2, 41, 26))
# Data(ssn='306-86-2930', last_updated=datetime.datetime(2017, 5, 10, 18, 3, 52), created=datetime.datetime(2016, 9, 15, 15, 20, 35))
# Data(ssn='308-58-0964', last_updated=datetime.datetime(2017, 6, 13, 11, 53, 43), created=datetime.datetime(2016, 9, 29, 22, 38, 39))
# Data(ssn='309-04-0364', last_updated=datetime.datetime(2018, 3, 23, 0, 53, 44), created=datetime.datetime(2016, 1, 18, 3, 37, 59))
# Data(ssn='309-38-8085', last_updated=datetime.datetime(2017, 10, 15, 2, 43, 14), created=datetime.datetime(2016, 5, 12, 11, 34, 16))
# Data(ssn='310-60-2027', last_updated=datetime.datetime(2018, 3, 20, 12, 53, 17), created=datetime.datetime(2016, 10, 25, 3, 4, 20))
# Data(ssn='311-46-9296', last_updated=datetime.datetime(2018, 2, 18, 15, 38, 24), created=datetime.datetime(2016, 8, 6, 19, 3, 48))
# Data(ssn='312-38-7084', last_updated=datetime.datetime(2017, 8, 7, 14, 33, 15), created=datetime.datetime(2016, 12, 1, 17, 51, 41))
# Data(ssn='312-59-3476', last_updated=datetime.datetime(2017, 6, 5, 16, 36, 40), created=datetime.datetime(2016, 6, 11, 17, 37, 47))
# Data(ssn='312-77-3647', last_updated=datetime.datetime(2017, 4, 30, 2, 56, 29), created=datetime.datetime(2016, 1, 13, 20, 57, 51))
# Data(ssn='313-02-7822', last_updated=datetime.datetime(2017, 10, 7, 16, 22, 13), created=datetime.datetime(2016, 12, 9, 3, 16, 22))
# Data(ssn='313-52-7312', last_updated=datetime.datetime(2017, 11, 27, 22, 37, 28), created=datetime.datetime(2016, 6, 9, 16, 42, 48))
# Data(ssn='315-12-5664', last_updated=datetime.datetime(2017, 6, 11, 18, 3, 12), created=datetime.datetime(2016, 5, 19, 13, 58, 32))
# Data(ssn='315-26-2241', last_updated=datetime.datetime(2017, 11, 27, 8, 16, 19), created=datetime.datetime(2016, 5, 27, 6, 53, 31))
# Data(ssn='315-44-9671', last_updated=datetime.datetime(2018, 3, 12, 23, 39, 35), created=datetime.datetime(2016, 10, 19, 9, 51, 9))
# Data(ssn='315-78-5587', last_updated=datetime.datetime(2017, 8, 20, 18, 9, 2), created=datetime.datetime(2016, 1, 17, 12, 12, 42))
# Data(ssn='317-28-1600', last_updated=datetime.datetime(2017, 12, 19, 2, 20, 21), created=datetime.datetime(2016, 10, 6, 3, 35, 19))
# Data(ssn='317-43-2055', last_updated=datetime.datetime(2017, 12, 26, 16, 31, 21), created=datetime.datetime(2016, 9, 18, 19, 55, 52))
# Data(ssn='318-58-5314', last_updated=datetime.datetime(2017, 3, 19, 17, 31, 18), created=datetime.datetime(2016, 11, 27, 19, 18, 57))
# Data(ssn='319-43-0465', last_updated=datetime.datetime(2018, 3, 8, 8, 22, 23), created=datetime.datetime(2016, 10, 30, 0, 3, 54))
# Data(ssn='320-90-1419', last_updated=datetime.datetime(2017, 8, 1, 15, 3, 18), created=datetime.datetime(2016, 5, 21, 16, 46, 58))
# Data(ssn='320-97-9147', last_updated=datetime.datetime(2017, 11, 27, 2, 56, 43), created=datetime.datetime(2016, 12, 30, 2, 58, 10))
# Data(ssn='323-28-6705', last_updated=datetime.datetime(2017, 7, 6, 8, 58, 57), created=datetime.datetime(2016, 9, 23, 12, 24, 33))
# Data(ssn='323-33-8689', last_updated=datetime.datetime(2018, 2, 6, 11, 18, 46), created=datetime.datetime(2016, 1, 30, 6, 55, 54))
# Data(ssn='324-39-5230', last_updated=datetime.datetime(2017, 12, 12, 18, 34, 16), created=datetime.datetime(2016, 8, 10, 15, 8, 1))
# Data(ssn='324-73-8895', last_updated=datetime.datetime(2018, 1, 31, 14, 40, 37), created=datetime.datetime(2016, 1, 31, 4, 8, 41))
# Data(ssn='324-75-6098', last_updated=datetime.datetime(2017, 3, 22, 10, 39, 27), created=datetime.datetime(2016, 11, 29, 5, 9, 44))
# Data(ssn='326-64-9957', last_updated=datetime.datetime(2017, 1, 28, 20, 25, 31), created=datetime.datetime(2016, 5, 21, 4, 5, 26))
# Data(ssn='327-52-0546', last_updated=datetime.datetime(2017, 11, 9, 16, 0, 25), created=datetime.datetime(2016, 6, 13, 20, 55, 47))
# Data(ssn='327-88-7554', last_updated=datetime.datetime(2017, 11, 24, 22, 24, 17), created=datetime.datetime(2016, 10, 12, 9, 25, 25))
# Data(ssn='330-99-3055', last_updated=datetime.datetime(2017, 3, 15, 2, 8, 35), created=datetime.datetime(2016, 6, 13, 6, 58, 21))
# Data(ssn='332-83-6591', last_updated=datetime.datetime(2017, 6, 1, 21, 27, 2), created=datetime.datetime(2016, 6, 26, 19, 28, 44))
# Data(ssn='333-52-5097', last_updated=datetime.datetime(2017, 8, 7, 15, 22, 28), created=datetime.datetime(2016, 10, 17, 19, 38, 37))
# Data(ssn='333-95-5025', last_updated=datetime.datetime(2017, 8, 28, 15, 13, 59), created=datetime.datetime(2016, 5, 25, 23, 33, 3))
# Data(ssn='335-35-1520', last_updated=datetime.datetime(2017, 1, 29, 15, 44, 57), created=datetime.datetime(2016, 11, 26, 7, 21, 10))
# Data(ssn='336-48-2579', last_updated=datetime.datetime(2018, 3, 2, 16, 26, 48), created=datetime.datetime(2016, 4, 28, 19, 21, 15))
# Data(ssn='339-27-8046', last_updated=datetime.datetime(2017, 12, 12, 18, 26, 28), created=datetime.datetime(2016, 4, 9, 3, 13, 49))
# Data(ssn='339-71-2687', last_updated=datetime.datetime(2017, 10, 22, 21, 42, 38), created=datetime.datetime(2016, 12, 18, 12, 54, 8))
# Data(ssn='341-10-6840', last_updated=datetime.datetime(2017, 3, 6, 16, 50, 4), created=datetime.datetime(2016, 6, 4, 11, 29, 46))
# Data(ssn='342-05-9057', last_updated=datetime.datetime(2017, 3, 23, 6, 34, 5), created=datetime.datetime(2016, 7, 19, 5, 33, 42))
# Data(ssn='342-55-0538', last_updated=datetime.datetime(2017, 8, 30, 11, 9, 11), created=datetime.datetime(2016, 1, 1, 10, 27, 44))
# Data(ssn='342-90-9333', last_updated=datetime.datetime(2017, 12, 2, 9, 54, 57), created=datetime.datetime(2016, 6, 17, 11, 46, 24))
# Data(ssn='343-20-8407', last_updated=datetime.datetime(2017, 12, 20, 4, 35, 7), created=datetime.datetime(2016, 5, 11, 2, 2, 53))
# Data(ssn='343-81-3179', last_updated=datetime.datetime(2017, 10, 17, 18, 21, 38), created=datetime.datetime(2016, 3, 6, 17, 25, 34))
# Data(ssn='345-74-2160', last_updated=datetime.datetime(2018, 2, 4, 4, 8, 54), created=datetime.datetime(2016, 7, 13, 23, 35, 12))
# Data(ssn='347-09-3254', last_updated=datetime.datetime(2017, 6, 30, 0, 52, 15), created=datetime.datetime(2016, 8, 15, 10, 51, 18))
# Data(ssn='347-64-8652', last_updated=datetime.datetime(2017, 5, 23, 11, 28, 5), created=datetime.datetime(2016, 12, 30, 3, 51, 10))
# Data(ssn='348-73-4312', last_updated=datetime.datetime(2017, 9, 13, 10, 31, 30), created=datetime.datetime(2016, 12, 14, 21, 16, 27))
# Data(ssn='348-74-3224', last_updated=datetime.datetime(2018, 2, 4, 18, 12, 54), created=datetime.datetime(2016, 5, 11, 22, 14, 46))
# Data(ssn='349-53-8864', last_updated=datetime.datetime(2017, 12, 27, 21, 15, 3), created=datetime.datetime(2016, 1, 28, 10, 14, 46))
# Data(ssn='349-67-7502', last_updated=datetime.datetime(2018, 2, 16, 4, 12, 54), created=datetime.datetime(2016, 1, 12, 23, 12, 17))
# Data(ssn='350-20-9593', last_updated=datetime.datetime(2018, 2, 10, 22, 55, 27), created=datetime.datetime(2016, 4, 12, 21, 1, 21))
# Data(ssn='350-80-4646', last_updated=datetime.datetime(2017, 8, 23, 16, 52, 47), created=datetime.datetime(2016, 5, 28, 8, 33, 21))
# Data(ssn='351-73-2802', last_updated=datetime.datetime(2017, 8, 11, 7, 49, 34), created=datetime.datetime(2016, 9, 3, 2, 20, 26))
# Data(ssn='355-21-9711', last_updated=datetime.datetime(2017, 11, 1, 23, 0, 15), created=datetime.datetime(2016, 4, 22, 13, 52, 40))
# Data(ssn='355-52-9767', last_updated=datetime.datetime(2018, 3, 20, 23, 3, 28), created=datetime.datetime(2016, 9, 25, 21, 5, 36))
# Data(ssn='355-96-7706', last_updated=datetime.datetime(2017, 10, 25, 11, 22, 28), created=datetime.datetime(2016, 3, 5, 8, 16, 19))
# Data(ssn='356-39-9199', last_updated=datetime.datetime(2017, 12, 4, 23, 53, 17), created=datetime.datetime(2016, 1, 28, 6, 55, 58))
# Data(ssn='357-37-6094', last_updated=datetime.datetime(2018, 2, 13, 5, 16, 10), created=datetime.datetime(2016, 4, 26, 4, 10, 52))
# Data(ssn='358-84-7049', last_updated=datetime.datetime(2017, 2, 9, 7, 24, 45), created=datetime.datetime(2016, 2, 21, 0, 13, 44))
# Data(ssn='360-69-6230', last_updated=datetime.datetime(2017, 5, 27, 8, 53, 14), created=datetime.datetime(2016, 12, 14, 18, 1, 16))
# Data(ssn='361-06-1530', last_updated=datetime.datetime(2017, 5, 6, 15, 5, 47), created=datetime.datetime(2016, 1, 21, 23, 6, 3))
# Data(ssn='361-42-7068', last_updated=datetime.datetime(2018, 2, 4, 13, 38, 12), created=datetime.datetime(2016, 9, 7, 15, 20, 13))
# Data(ssn='361-49-4597', last_updated=datetime.datetime(2017, 11, 22, 9, 17, 58), created=datetime.datetime(2016, 12, 20, 11, 29, 30))
# Data(ssn='361-83-5004', last_updated=datetime.datetime(2017, 8, 11, 21, 27, 23), created=datetime.datetime(2016, 12, 24, 3, 19, 11))
# Data(ssn='362-09-8563', last_updated=datetime.datetime(2017, 2, 7, 23, 59, 48), created=datetime.datetime(2016, 7, 4, 3, 26, 36))
# Data(ssn='362-12-7902', last_updated=datetime.datetime(2017, 4, 13, 22, 21, 36), created=datetime.datetime(2016, 7, 11, 7, 18, 59))
# Data(ssn='364-25-0166', last_updated=datetime.datetime(2017, 10, 23, 16, 31, 42), created=datetime.datetime(2016, 4, 29, 17, 41, 2))
# Data(ssn='364-65-2174', last_updated=datetime.datetime(2017, 5, 22, 4, 28, 40), created=datetime.datetime(2016, 5, 30, 8, 50, 2))
# Data(ssn='366-61-0607', last_updated=datetime.datetime(2017, 12, 27, 23, 53, 19), created=datetime.datetime(2016, 3, 28, 15, 11, 41))
# Data(ssn='367-22-8998', last_updated=datetime.datetime(2017, 12, 11, 17, 58, 1), created=datetime.datetime(2016, 5, 13, 12, 0, 26))
# Data(ssn='367-62-4426', last_updated=datetime.datetime(2017, 5, 26, 3, 1, 24), created=datetime.datetime(2016, 9, 6, 12, 15, 56))
# Data(ssn='370-01-6977', last_updated=datetime.datetime(2017, 1, 16, 16, 48, 28), created=datetime.datetime(2016, 6, 17, 10, 50, 49))
# Data(ssn='370-24-5876', last_updated=datetime.datetime(2018, 3, 10, 11, 48, 29), created=datetime.datetime(2016, 10, 18, 8, 30, 53))
# Data(ssn='370-72-6509', last_updated=datetime.datetime(2017, 4, 26, 2, 36, 25), created=datetime.datetime(2016, 10, 28, 4, 26, 21))
# Data(ssn='371-28-5892', last_updated=datetime.datetime(2017, 10, 23, 5, 51, 2), created=datetime.datetime(2016, 11, 1, 11, 0, 34))
# Data(ssn='371-44-0582', last_updated=datetime.datetime(2017, 10, 23, 21, 19, 7), created=datetime.datetime(2016, 12, 12, 22, 59, 7))
# Data(ssn='371-62-3727', last_updated=datetime.datetime(2017, 7, 26, 23, 48, 15), created=datetime.datetime(2016, 8, 16, 8, 13, 41))
# Data(ssn='371-88-9249', last_updated=datetime.datetime(2017, 3, 5, 20, 51, 30), created=datetime.datetime(2016, 9, 15, 17, 57, 18))
# ...
# Data(ssn='797-65-2382', last_updated=datetime.datetime(2017, 1, 24, 12, 7, 57), created=datetime.datetime(2016, 2, 25, 16, 22, 8))
# Data(ssn='797-87-7992', last_updated=datetime.datetime(2018, 2, 24, 14, 55, 36), created=datetime.datetime(2016, 10, 19, 9, 48, 40))
# Data(ssn='798-34-1082', last_updated=datetime.datetime(2017, 3, 22, 13, 48, 42), created=datetime.datetime(2016, 7, 18, 12, 49, 34))
# Data(ssn='798-65-5644', last_updated=datetime.datetime(2017, 11, 29, 5, 3, 57), created=datetime.datetime(2016, 12, 5, 4, 31, 19))
# Data(ssn='800-06-9721', last_updated=datetime.datetime(2017, 6, 15, 11, 45, 18), created=datetime.datetime(2016, 10, 6, 4, 19, 10))
# Data(ssn='801-08-8313', last_updated=datetime.datetime(2017, 6, 6, 18, 4, 7), created=datetime.datetime(2016, 2, 17, 16, 51, 58))
# Data(ssn='801-92-6460', last_updated=datetime.datetime(2017, 5, 30, 19, 12, 17), created=datetime.datetime(2016, 11, 3, 7, 17, 1))
# Data(ssn='801-99-2773', last_updated=datetime.datetime(2017, 8, 21, 10, 25, 47), created=datetime.datetime(2016, 7, 26, 8, 24, 12))
# Data(ssn='804-46-0617', last_updated=datetime.datetime(2017, 6, 9, 18, 37, 10), created=datetime.datetime(2016, 11, 6, 6, 36, 15))
# Data(ssn='807-13-5922', last_updated=datetime.datetime(2017, 3, 12, 16, 29, 50), created=datetime.datetime(2016, 6, 17, 23, 4, 5))
# Data(ssn='807-24-6202', last_updated=datetime.datetime(2017, 12, 22, 4, 19, 35), created=datetime.datetime(2016, 2, 20, 3, 53, 16))
# Data(ssn='807-25-6136', last_updated=datetime.datetime(2017, 7, 10, 21, 58, 9), created=datetime.datetime(2016, 6, 30, 11, 32, 14))
# Data(ssn='807-35-8936', last_updated=datetime.datetime(2017, 3, 10, 8, 11, 51), created=datetime.datetime(2016, 5, 20, 15, 53, 34))
# Data(ssn='807-50-8539', last_updated=datetime.datetime(2017, 8, 25, 17, 2, 7), created=datetime.datetime(2016, 11, 17, 19, 43, 48))
# Data(ssn='807-60-5615', last_updated=datetime.datetime(2017, 1, 20, 8, 10, 18), created=datetime.datetime(2016, 1, 21, 10, 4))
# Data(ssn='808-55-8658', last_updated=datetime.datetime(2017, 9, 30, 9, 38, 27), created=datetime.datetime(2016, 9, 23, 12, 37, 50))
# Data(ssn='808-80-2542', last_updated=datetime.datetime(2018, 1, 3, 12, 45, 59), created=datetime.datetime(2016, 2, 2, 4, 18, 46))
# Data(ssn='811-65-2750', last_updated=datetime.datetime(2017, 6, 11, 23, 31, 14), created=datetime.datetime(2016, 2, 20, 8, 23, 25))
# Data(ssn='812-11-9403', last_updated=datetime.datetime(2017, 5, 15, 16, 9, 23), created=datetime.datetime(2016, 8, 30, 15, 39, 9))
# Data(ssn='813-42-4142', last_updated=datetime.datetime(2017, 10, 17, 13, 20, 22), created=datetime.datetime(2016, 3, 3, 4, 54, 4))
# Data(ssn='813-47-5215', last_updated=datetime.datetime(2017, 7, 17, 0, 22, 1), created=datetime.datetime(2016, 10, 2, 5, 4, 12))
# Data(ssn='815-83-0300', last_updated=datetime.datetime(2017, 9, 24, 5, 16, 56), created=datetime.datetime(2016, 5, 30, 2, 41, 36))
# Data(ssn='816-31-3858', last_updated=datetime.datetime(2017, 4, 13, 4, 17, 11), created=datetime.datetime(2016, 7, 30, 2, 46, 27))
# Data(ssn='816-47-4782', last_updated=datetime.datetime(2017, 9, 9, 12, 11, 28), created=datetime.datetime(2016, 11, 24, 12, 43, 20))
# Data(ssn='816-90-2049', last_updated=datetime.datetime(2018, 2, 16, 1, 29, 23), created=datetime.datetime(2016, 10, 25, 7, 25, 19))
# Data(ssn='817-04-1950', last_updated=datetime.datetime(2017, 5, 24, 8, 43, 21), created=datetime.datetime(2016, 7, 2, 12, 4, 51))
# Data(ssn='817-25-7437', last_updated=datetime.datetime(2017, 11, 27, 5, 44, 31), created=datetime.datetime(2016, 7, 6, 6, 49, 2))
# Data(ssn='817-80-8930', last_updated=datetime.datetime(2017, 10, 15, 5, 52, 17), created=datetime.datetime(2016, 1, 25, 15, 9, 1))
# Data(ssn='818-61-0770', last_updated=datetime.datetime(2017, 11, 24, 15, 25, 51), created=datetime.datetime(2016, 8, 12, 7, 54, 17))
# Data(ssn='819-52-5886', last_updated=datetime.datetime(2018, 2, 24, 20, 44, 53), created=datetime.datetime(2016, 3, 2, 2, 24, 48))
# Data(ssn='819-64-1414', last_updated=datetime.datetime(2017, 8, 26, 5, 23, 58), created=datetime.datetime(2016, 12, 12, 12, 4, 14))
# Data(ssn='820-96-1105', last_updated=datetime.datetime(2017, 6, 11, 20, 41, 22), created=datetime.datetime(2016, 2, 14, 2, 38, 15))
# Data(ssn='822-05-9037', last_updated=datetime.datetime(2017, 11, 14, 6, 43, 11), created=datetime.datetime(2016, 3, 28, 1, 5, 25))
# Data(ssn='822-30-4861', last_updated=datetime.datetime(2018, 3, 6, 15, 41, 52), created=datetime.datetime(2016, 11, 5, 5, 11, 25))
# Data(ssn='823-27-0762', last_updated=datetime.datetime(2017, 7, 9, 16, 33, 59), created=datetime.datetime(2016, 4, 19, 13, 46, 43))
# Data(ssn='823-75-5753', last_updated=datetime.datetime(2017, 11, 26, 1, 36, 57), created=datetime.datetime(2016, 1, 27, 23, 15, 38))
# Data(ssn='824-89-4169', last_updated=datetime.datetime(2017, 3, 30, 13, 22, 12), created=datetime.datetime(2016, 11, 16, 16, 43, 21))
# Data(ssn='826-97-8029', last_updated=datetime.datetime(2018, 2, 26, 23, 21, 58), created=datetime.datetime(2016, 5, 15, 14, 51, 21))
# Data(ssn='827-62-4599', last_updated=datetime.datetime(2017, 3, 15, 23, 54, 1), created=datetime.datetime(2016, 5, 21, 18, 17, 57))
# Data(ssn='830-23-1573', last_updated=datetime.datetime(2017, 2, 20, 23, 42), created=datetime.datetime(2016, 9, 1, 0, 6, 49))
# Data(ssn='831-44-3286', last_updated=datetime.datetime(2017, 2, 19, 2, 38, 55), created=datetime.datetime(2016, 5, 5, 3, 7, 14))
# Data(ssn='833-01-1428', last_updated=datetime.datetime(2017, 9, 22, 5, 7, 13), created=datetime.datetime(2016, 12, 14, 4, 3, 53))
# Data(ssn='835-54-3785', last_updated=datetime.datetime(2017, 6, 10, 8, 36, 26), created=datetime.datetime(2016, 10, 4, 20, 10, 40))
# Data(ssn='836-40-1837', last_updated=datetime.datetime(2017, 11, 13, 6, 7, 5), created=datetime.datetime(2016, 2, 13, 5, 4, 28))
# Data(ssn='836-99-3309', last_updated=datetime.datetime(2018, 1, 4, 11, 10, 54), created=datetime.datetime(2016, 9, 30, 11, 25, 21))
# Data(ssn='837-76-5619', last_updated=datetime.datetime(2017, 6, 28, 8, 29, 54), created=datetime.datetime(2016, 11, 3, 20, 8, 35))
# Data(ssn='838-69-1351', last_updated=datetime.datetime(2017, 12, 30, 1, 53, 27), created=datetime.datetime(2016, 4, 27, 22, 22, 15))
# Data(ssn='840-41-7929', last_updated=datetime.datetime(2017, 7, 21, 4, 56, 59), created=datetime.datetime(2016, 2, 14, 6, 25, 5))
# Data(ssn='841-64-8517', last_updated=datetime.datetime(2017, 12, 17, 5, 13, 41), created=datetime.datetime(2016, 6, 28, 23, 17, 28))
# Data(ssn='842-90-7557', last_updated=datetime.datetime(2017, 5, 13, 22, 21, 23), created=datetime.datetime(2016, 5, 30, 14, 24, 20))
# Data(ssn='844-15-4668', last_updated=datetime.datetime(2017, 7, 9, 22, 12, 16), created=datetime.datetime(2016, 3, 27, 2, 46, 16))
# Data(ssn='844-50-7305', last_updated=datetime.datetime(2018, 1, 30, 7, 49, 7), created=datetime.datetime(2016, 8, 16, 12, 42, 56))
# Data(ssn='846-07-1407', last_updated=datetime.datetime(2017, 7, 10, 17, 48, 49), created=datetime.datetime(2016, 3, 5, 11, 53, 15))
# Data(ssn='846-09-9851', last_updated=datetime.datetime(2017, 1, 25, 3, 3, 59), created=datetime.datetime(2016, 4, 26, 18, 41, 28))
# Data(ssn='846-59-9961', last_updated=datetime.datetime(2017, 2, 20, 3, 4, 34), created=datetime.datetime(2016, 12, 28, 20, 41, 47))
# Data(ssn='847-34-4817', last_updated=datetime.datetime(2017, 2, 13, 3, 31, 14), created=datetime.datetime(2016, 2, 2, 21, 15, 15))
# Data(ssn='847-61-7656', last_updated=datetime.datetime(2017, 12, 19, 9, 38, 38), created=datetime.datetime(2016, 1, 30, 9, 5, 32))
# Data(ssn='848-58-3386', last_updated=datetime.datetime(2018, 1, 21, 4, 10, 3), created=datetime.datetime(2016, 3, 18, 1, 51, 27))
# Data(ssn='848-74-2886', last_updated=datetime.datetime(2017, 4, 28, 22, 57, 18), created=datetime.datetime(2016, 3, 16, 18, 7, 48))
# Data(ssn='848-76-8808', last_updated=datetime.datetime(2017, 1, 9, 20, 35, 16), created=datetime.datetime(2016, 8, 6, 21, 44, 44))
# Data(ssn='849-31-1551', last_updated=datetime.datetime(2017, 7, 22, 6, 54, 46), created=datetime.datetime(2016, 4, 1, 21, 35, 44))
# Data(ssn='849-64-6624', last_updated=datetime.datetime(2018, 3, 23, 20, 28, 43), created=datetime.datetime(2016, 1, 10, 18, 3, 17))
# Data(ssn='849-98-2973', last_updated=datetime.datetime(2017, 8, 20, 13, 10, 57), created=datetime.datetime(2016, 2, 26, 2, 40, 54))
# Data(ssn='851-94-2162', last_updated=datetime.datetime(2017, 10, 15, 12, 43, 2), created=datetime.datetime(2016, 11, 28, 14, 34, 31))
# Data(ssn='852-15-7707', last_updated=datetime.datetime(2017, 12, 7, 23, 31, 37), created=datetime.datetime(2016, 3, 17, 17, 39, 10))
# Data(ssn='853-11-8953', last_updated=datetime.datetime(2017, 12, 30, 0, 36, 43), created=datetime.datetime(2016, 12, 24, 23, 34, 4))
# Data(ssn='853-47-3648', last_updated=datetime.datetime(2017, 11, 24, 19, 37, 50), created=datetime.datetime(2016, 4, 22, 21, 36, 41))
# Data(ssn='854-68-7635', last_updated=datetime.datetime(2017, 5, 16, 14, 22, 39), created=datetime.datetime(2016, 4, 29, 5, 3, 11))
# Data(ssn='854-71-2983', last_updated=datetime.datetime(2017, 9, 6, 20, 53, 9), created=datetime.datetime(2016, 11, 7, 5, 47, 14))
# Data(ssn='854-79-5334', last_updated=datetime.datetime(2017, 8, 29, 17, 57, 56), created=datetime.datetime(2016, 3, 27, 18, 30, 18))
# Data(ssn='856-18-3980', last_updated=datetime.datetime(2017, 1, 20, 20, 28, 10), created=datetime.datetime(2016, 12, 8, 6, 52, 33))
# Data(ssn='856-27-9112', last_updated=datetime.datetime(2017, 12, 25, 10, 25, 28), created=datetime.datetime(2016, 3, 24, 4, 1, 59))
# Data(ssn='856-67-4080', last_updated=datetime.datetime(2018, 3, 13, 21, 23, 9), created=datetime.datetime(2016, 6, 22, 3, 53, 18))
# Data(ssn='857-37-5902', last_updated=datetime.datetime(2018, 1, 20, 14, 44, 7), created=datetime.datetime(2016, 10, 23, 21, 56, 28))
# Data(ssn='858-03-7735', last_updated=datetime.datetime(2017, 4, 30, 8, 14, 24), created=datetime.datetime(2016, 9, 4, 8, 24, 3))
# Data(ssn='858-27-9190', last_updated=datetime.datetime(2017, 2, 6, 7, 12, 2), created=datetime.datetime(2016, 12, 25, 16, 52, 9))
# Data(ssn='860-67-0256', last_updated=datetime.datetime(2017, 1, 9, 22, 49, 48), created=datetime.datetime(2016, 2, 6, 4, 59, 26))
# Data(ssn='860-89-2570', last_updated=datetime.datetime(2017, 4, 15, 11, 12, 57), created=datetime.datetime(2016, 6, 22, 23, 23, 9))
# Data(ssn='861-50-6716', last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34))
# Data(ssn='862-20-0653', last_updated=datetime.datetime(2017, 5, 3, 14, 37, 42), created=datetime.datetime(2016, 2, 4, 14, 11, 40))
# Data(ssn='864-22-9364', last_updated=datetime.datetime(2017, 2, 4, 13, 53, 10), created=datetime.datetime(2016, 12, 28, 0, 33, 8))
# Data(ssn='864-91-7489', last_updated=datetime.datetime(2017, 2, 3, 17, 51, 18), created=datetime.datetime(2016, 2, 14, 3, 7, 23))
# Data(ssn='866-18-1440', last_updated=datetime.datetime(2017, 5, 31, 4, 28, 19), created=datetime.datetime(2016, 2, 2, 17, 47, 22))
# Data(ssn='866-53-0625', last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20))
# Data(ssn='867-11-6007', last_updated=datetime.datetime(2018, 1, 25, 4, 2, 4), created=datetime.datetime(2016, 10, 31, 14, 12, 16))
# Data(ssn='867-13-6844', last_updated=datetime.datetime(2017, 10, 31, 17, 48, 23), created=datetime.datetime(2016, 7, 17, 9, 50, 7))
# Data(ssn='867-88-2360', last_updated=datetime.datetime(2018, 3, 11, 16, 42, 31), created=datetime.datetime(2016, 11, 4, 18, 34, 52))
# Data(ssn='868-32-1805', last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32))
# Data(ssn='870-12-6609', last_updated=datetime.datetime(2017, 1, 19, 3, 43, 35), created=datetime.datetime(2016, 6, 24, 16, 43, 15))
# Data(ssn='870-93-1121', last_updated=datetime.datetime(2017, 3, 3, 3, 45, 30), created=datetime.datetime(2016, 6, 21, 17, 1, 53))
# Data(ssn='871-99-3191', last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26))
# Data(ssn='872-18-9267', last_updated=datetime.datetime(2018, 3, 22, 21, 11, 58), created=datetime.datetime(2016, 4, 27, 3, 27, 17))
# Data(ssn='872-49-1288', last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19))
# Data(ssn='873-36-4733', last_updated=datetime.datetime(2017, 7, 23, 1, 30, 5), created=datetime.datetime(2016, 7, 8, 7, 10, 52))
# Data(ssn='875-18-9454', last_updated=datetime.datetime(2017, 3, 14, 4, 45, 19), created=datetime.datetime(2016, 8, 19, 18, 23, 57))
# Data(ssn='875-75-0495', last_updated=datetime.datetime(2017, 12, 3, 21, 27, 47), created=datetime.datetime(2016, 6, 12, 12, 36, 44))
# Data(ssn='878-12-8265', last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37))
# Data(ssn='880-22-4449', last_updated=datetime.datetime(2017, 1, 13, 19, 50, 26), created=datetime.datetime(2016, 6, 11, 20, 35, 38))
# Data(ssn='881-19-5974', last_updated=datetime.datetime(2018, 2, 4, 17, 29, 28), created=datetime.datetime(2016, 10, 5, 21, 57, 12))
# Data(ssn='881-88-7308', last_updated=datetime.datetime(2017, 8, 11, 11, 40, 28), created=datetime.datetime(2016, 1, 18, 12, 51))
# Data(ssn='881-95-7180', last_updated=datetime.datetime(2018, 1, 29, 16, 6, 26), created=datetime.datetime(2016, 11, 24, 12, 12, 51))
# Data(ssn='882-49-5290', last_updated=datetime.datetime(2017, 2, 10, 19, 26, 8), created=datetime.datetime(2016, 8, 27, 5, 43, 5))
# Data(ssn='884-61-1852', last_updated=datetime.datetime(2017, 1, 9, 19, 30, 49), created=datetime.datetime(2016, 3, 18, 22, 13, 6))
# Data(ssn='887-41-7878', last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53))
# Data(ssn='887-83-9002', last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28))
# Data(ssn='888-50-7008', last_updated=datetime.datetime(2018, 3, 6, 16, 54, 20), created=datetime.datetime(2016, 6, 9, 11, 3, 40))
# Data(ssn='888-53-7684', last_updated=datetime.datetime(2017, 9, 5, 0, 30), created=datetime.datetime(2016, 2, 12, 1, 35, 59))
# Data(ssn='888-82-4928', last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16))
# Data(ssn='890-28-9962', last_updated=datetime.datetime(2018, 1, 6, 9, 34, 59), created=datetime.datetime(2016, 2, 22, 15, 24, 59))
# Data(ssn='893-12-0901', last_updated=datetime.datetime(2018, 3, 27, 1, 24, 58), created=datetime.datetime(2016, 6, 14, 2, 41, 25))
# Data(ssn='893-17-7318', last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12))
# Data(ssn='894-81-0628', last_updated=datetime.datetime(2017, 3, 7, 4, 8, 28), created=datetime.datetime(2016, 7, 9, 11, 43, 17))
# Data(ssn='895-26-1658', last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45))
# Data(ssn='895-26-5515', last_updated=datetime.datetime(2017, 5, 13, 5, 52, 27), created=datetime.datetime(2016, 3, 24, 7, 34, 14))
# Data(ssn='897-76-7070', last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48))
# Data(ssn='898-03-3165', last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2))
# Data(ssn='898-86-8860', last_updated=datetime.datetime(2017, 7, 3, 14, 27, 26), created=datetime.datetime(2016, 11, 23, 23, 34, 17))
# Data(ssn='899-09-1766', last_updated=datetime.datetime(2017, 7, 31, 2, 26, 57), created=datetime.datetime(2016, 10, 27, 18, 41, 56))
# Data(ssn='899-39-7179', last_updated=datetime.datetime(2017, 8, 2, 13, 32, 33), created=datetime.datetime(2016, 7, 27, 12, 47, 5))
# Data(ssn='899-39-7378', last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22))
# Data(ssn='899-47-6116', last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23))

# %% [markdown]
# ### GOAL - 2

# %%
from collections import namedtuple
from csv import reader
from datetime import datetime

HEADER = []

def generate(file_name: str):
    def create_tuple(iterator):
        header = next(iterator)
        HEADER.append(header)
        return namedtuple('Data', header)

    def convert(row, mode):
        if mode == 'update_status.csv':
            format = '%Y-%m-%dT%H:%M:%SZ'
            row[1], row[2] = datetime.strptime(row[1], format), datetime.strptime(row[2], format)

        elif mode == 'vehicles.csv':
            row[-1] = int(row[-1])

    with open(file_name) as f:
        data = reader(f, lineterminator='\n')
        Data = create_tuple(data)

        for row in data:
            convert(row, file_name)
            yield Data(*row)

def all_data():
    def create_tuple(header):
        values = []

        for head in header:
            for value in head:
                if value not in values:
                    values.append(value)

        return namedtuple('Data', values)

    gen_lst = [generate(file)
               for file in ('personal_info.csv', 'employment.csv', 'update_status.csv', 'vehicles.csv')]
    iter1, iter2, iter3, iter4 = gen_lst
    _ = next(iter1), next(iter2), next(iter3), next(iter4)
    Data = create_tuple(HEADER)

    while True:
        try:
            data1, data2, data3, data4 = next(iter1), next(iter2), next(iter3), next(iter4)
            all_data = data1 + data2[:-1] + data3[1:] + data4[1:]
            yield Data(*all_data)

        except StopIteration:
            break

# %%
for data in all_data():
    print(data)
# Out:
# Data(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', employer='Nicolas and Sons', department='Sales', employee_id='41-6841359', last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57), vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# Data(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', employer='Connelly Group', department='Research and Development', employee_id='98-7952860', last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7), vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# Data(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', employer='Upton LLC', department='Marketing', employee_id='56-9817552', last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17), vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# Data(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', employer='Zemlak-Olson', department='Business Development', employee_id='46-2886707', last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57), vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)
# Data(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', employer='Kohler, Bradtke and Davis', department='Support', employee_id='80-0975518', last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35), vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# Data(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', employer='Roberts, Torphy and Dach', department='Human Resources', employee_id='77-4895332', last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43), vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# Data(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', employer='Lind-Jast', department='Marketing', employee_id='79-6418731', last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3), vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000)
# Data(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian', employer='Bashirian-Lueilwitz', department='Engineering', employee_id='44-3328799', last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13), vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# Data(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', employer='Windler, Marks and Haley', department='Services', employee_id='54-6271885', last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12), vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992)
# Data(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', employer='Leffler-Hahn', department='Accounting', employee_id='31-5735282', last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Data(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', employer='Lueilwitz LLC', department='Marketing', employee_id='33-9146042', last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5), vehicle_make='Ford', vehicle_model='Mustang', model_year=1990)
# Data(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', employer='Davis Inc', department='Accounting', employee_id='39-0400385', last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17), vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# Data(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch', employer='Kunze LLC', department='Research and Development', employee_id='78-2612900', last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3), vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011)
# Data(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', employer='Mayert, Rice and Schmitt', department='Product Management', employee_id='85-8596488', last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25), vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# Data(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', employer='Pouros LLC', department='Legal', employee_id='14-2589283', last_updated=datetime.datetime(2017, 10, 30, 23, 54, 38), created=datetime.datetime(2016, 6, 4, 5, 18, 3), vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009)
# Data(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', employer='Pfannerstill Group', department='Research and Development', employee_id='43-1532437', last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26), vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009)
# Data(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian', employer='Ryan Group', department='Sales', employee_id='08-8274517', last_updated=datetime.datetime(2017, 11, 21, 14, 25, 11), created=datetime.datetime(2016, 7, 3, 3, 55, 39), vehicle_make='Buick', vehicle_model='Rainier', model_year=2004)
# Data(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', employer='Ritchie-Pagac', department='Business Development', employee_id='38-0095184', last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17), vehicle_make='Scion', vehicle_model='tC', model_year=2008)
# Data(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew', employer='Schmeler and Sons', department='Research and Development', employee_id='62-3275199', last_updated=datetime.datetime(2017, 2, 18, 23, 9, 25), created=datetime.datetime(2016, 2, 2, 15, 41, 42), vehicle_make='Audi', vehicle_model='S6', model_year=2009)
# Data(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', employer='Kerluke-Dibbert', department='Services', employee_id='90-5121197', last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1), vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007)
# Data(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', employer='Hane-Klocko', department='Human Resources', employee_id='27-2946273', last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992)
# Data(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', employer='Ernser LLC', department='Services', employee_id='07-6466085', last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Data(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', employer='Terry LLC', department='Accounting', employee_id='70-4864087', last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005)
# Data(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', employer='Rolfson, Price and Crooks', department='Business Development', employee_id='77-0255816', last_updated=datetime.datetime(2017, 11, 11, 8, 53, 11), created=datetime.datetime(2016, 7, 10, 20, 49), vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997)
# Data(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', employer='Romaguera, Welch and Haley', department='Engineering', employee_id='14-6523887', last_updated=datetime.datetime(2017, 12, 1, 17, 30, 55), created=datetime.datetime(2016, 7, 23, 15, 52, 53), vehicle_make='Acura', vehicle_model='RL', model_year=2003)
# Data(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', employer='Paucek, Huels and Bauch', department='Accounting', employee_id='21-1452824', last_updated=datetime.datetime(2017, 8, 23, 16, 0, 57), created=datetime.datetime(2016, 6, 26, 23, 46, 48), vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002)
# Data(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', employer='Hayes-Trantow', department='Support', employee_id='07-2855255', last_updated=datetime.datetime(2017, 8, 16, 12, 8, 6), created=datetime.datetime(2016, 10, 23, 13, 32, 13), vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# Data(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id='57-1590433', last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5), vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999)
# Data(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', employer='Mueller-Rath', department='Human Resources', employee_id='05-8069298', last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36), vehicle_make='Ford', vehicle_model='Mustang', model_year=1989)
# Data(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian', employer='Schumm, Schumm and Reichert', department='Engineering', employee_id='73-3839744', last_updated=datetime.datetime(2017, 2, 7, 14, 36, 31), created=datetime.datetime(2016, 7, 8, 17, 46, 23), vehicle_make='Lexus', vehicle_model='RX', model_year=2010)
# Data(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', employer='Tromp-Leffler', department='Support', employee_id='02-6267170', last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004)
# Data(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara', employer='Wolf LLC', department='Engineering', employee_id='53-8370994', last_updated=datetime.datetime(2017, 1, 12, 9, 42, 31), created=datetime.datetime(2016, 10, 9, 1, 14, 36), vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008)
# Data(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', employer='Kulas-Corwin', department='Sales', employee_id='78-0632027', last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21), vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# Data(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', employer='MacGyver, Wiegand and Grant', department='Product Management', employee_id='77-4182531', last_updated=datetime.datetime(2017, 9, 10, 6, 24, 19), created=datetime.datetime(2016, 7, 23, 1, 30, 3), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007)
# Data(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian', employer="Kertzmann-O'Hara", department='Sales', employee_id='44-8015165', last_updated=datetime.datetime(2017, 1, 29, 20, 31, 15), created=datetime.datetime(2016, 7, 13, 9, 52, 36), vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006)
# Data(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', employer='Vandervort, Bernier and Morissette', department='Human Resources', employee_id='14-4998615', last_updated=datetime.datetime(2017, 8, 10, 21, 18), created=datetime.datetime(2016, 12, 19, 21, 37, 6), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Data(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', employer='King-Donnelly', department='Training', employee_id='82-0573004', last_updated=datetime.datetime(2017, 8, 31, 16, 42, 23), created=datetime.datetime(2016, 7, 29, 3, 46, 26), vehicle_make='Dodge', vehicle_model='Neon', model_year=1995)
# Data(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', employer='Harris Inc', department='Support', employee_id='53-7535536', last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56), vehicle_make='BMW', vehicle_model='M', model_year=2001)
# Data(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech', employer='Heidenreich, Bergnaum and Smith', department='Training', employee_id='04-7204163', last_updated=datetime.datetime(2017, 1, 3, 20, 33, 45), created=datetime.datetime(2016, 3, 18, 11, 18, 14), vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988)
# Data(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha', employer='Altenwerth-Heidenreich', department='Research and Development', employee_id='58-3628686', last_updated=datetime.datetime(2017, 2, 11, 10, 18, 21), created=datetime.datetime(2016, 12, 12, 5, 1, 34), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993)
# Data(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', employer='Gibson and Sons', department='Sales', employee_id='57-8173633', last_updated=datetime.datetime(2018, 3, 21, 12, 2, 31), created=datetime.datetime(2016, 2, 3, 23, 26, 27), vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012)
# Data(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi', employer='Rodriguez LLC', department='Legal', employee_id='65-7310166', last_updated=datetime.datetime(2017, 1, 19, 7, 33, 37), created=datetime.datetime(2016, 5, 20, 1, 41, 54), vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992)
# Data(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', employer='Donnelly-Crooks', department='Human Resources', employee_id='22-2943669', last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40), vehicle_make='BMW', vehicle_model='M5', model_year=2006)
# Data(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', employer='Hyatt LLC', department='Training', employee_id='96-9647102', last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17), vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004)
# Data(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', employer='Schuster Group', department='Research and Development', employee_id='72-4728604', last_updated=datetime.datetime(2017, 12, 24, 9, 44, 10), created=datetime.datetime(2016, 3, 1, 19, 9, 29), vehicle_make='Infiniti', vehicle_model='G', model_year=2005)
# Data(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', employer='Homenick-Beer', department='Product Management', employee_id='01-9334133', last_updated=datetime.datetime(2017, 4, 17, 16, 30, 2), created=datetime.datetime(2016, 12, 17, 7, 7, 47), vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992)
# Data(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', employer='VonRueden-Torphy', department='Business Development', employee_id='10-6636122', last_updated=datetime.datetime(2018, 3, 4, 8, 14, 31), created=datetime.datetime(2016, 9, 24, 1, 52, 46), vehicle_make='Lexus', vehicle_model='RX', model_year=2003)
# Data(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese', employer='Mohr, Harvey and Mitchell', department='Legal', employee_id='64-7550101', last_updated=datetime.datetime(2017, 2, 24, 15, 47, 36), created=datetime.datetime(2016, 1, 4, 9, 37, 53), vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004)
# Data(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian', employer='Keeling-Schroeder', department='Engineering', employee_id='82-2479019', last_updated=datetime.datetime(2017, 2, 16, 21, 23, 10), created=datetime.datetime(2016, 5, 24, 4, 10, 50), vehicle_make='Ford', vehicle_model='Escort', model_year=1997)
# Data(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', employer='Gusikowski-Block', department='Legal', employee_id='41-1454732', last_updated=datetime.datetime(2017, 8, 19, 16, 22, 52), created=datetime.datetime(2016, 9, 10, 21, 9, 28), vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990)
# Data(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', employer='Pollich-Heathcote', department='Product Management', employee_id='12-2844710', last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20), vehicle_make='Volvo', vehicle_model='V70', model_year=2002)
# Data(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', employer='Bogisich Inc', department='Human Resources', employee_id='34-7172919', last_updated=datetime.datetime(2017, 9, 21, 23, 4, 48), created=datetime.datetime(2016, 1, 27, 9, 2, 26), vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# Data(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori', employer='Gutkowski Inc', department='Engineering', employee_id='83-4836768', last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22), vehicle_make='Volvo', vehicle_model='XC90', model_year=2009)
# Data(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', employer='Greenholt LLC', department='Sales', employee_id='84-5391800', last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37), vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000)
# Data(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', employer='Hartmann Inc', department='Support', employee_id='26-7276512', last_updated=datetime.datetime(2018, 1, 24, 20, 0, 4), created=datetime.datetime(2016, 12, 20, 0, 43, 43), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Data(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', employer='Zboncak-Gulgowski', department='Marketing', employee_id='05-0368584', last_updated=datetime.datetime(2017, 7, 16, 15, 12, 37), created=datetime.datetime(2016, 7, 30, 13, 28, 38), vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999)
# Data(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', employer='Altenwerth-Emard', department='Marketing', employee_id='30-5847411', last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005)
# Data(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', employer='Cronin Inc', department='Business Development', employee_id='08-3106397', last_updated=datetime.datetime(2017, 7, 21, 18, 54, 47), created=datetime.datetime(2016, 2, 9, 6, 10, 21), vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# Data(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese', employer='Murray, Wolff and Little', department='Business Development', employee_id='29-3578815', last_updated=datetime.datetime(2017, 1, 18, 6, 37, 31), created=datetime.datetime(2016, 4, 25, 21, 45), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Data(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', employer='Dibbert LLC', department='Support', employee_id='09-9620598', last_updated=datetime.datetime(2018, 2, 20, 12, 47, 43), created=datetime.datetime(2016, 10, 3, 5, 18, 6), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Data(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', employer='Tromp Inc', department='Research and Development', employee_id='06-3360383', last_updated=datetime.datetime(2017, 6, 10, 6, 21, 46), created=datetime.datetime(2016, 9, 23, 15, 35, 52), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993)
# Data(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', employer='Kub, Koch and Ratke', department='Marketing', employee_id='72-7830449', last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988)
# Data(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', employer='Greenholt-Gusikowski', department='Engineering', employee_id='16-6006875', last_updated=datetime.datetime(2018, 2, 9, 4, 41, 58), created=datetime.datetime(2016, 5, 31, 23, 38, 59), vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995)
# Data(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', employer='Tremblay, Jacobs and Swift', department='Training', employee_id='46-1648855', last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36), vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996)
# Data(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', employer='Bashirian-Moen', department='Training', employee_id='51-9115041', last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52), vehicle_make='Ford', vehicle_model='Explorer', model_year=2005)
# Data(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', employer='Hudson-Gerhold', department='Human Resources', employee_id='62-2244500', last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29), vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992)
# Data(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', employer='Balistreri Inc', department='Sales', employee_id='92-8183627', last_updated=datetime.datetime(2017, 8, 31, 2, 41, 41), created=datetime.datetime(2016, 10, 21, 12, 17, 57), vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992)
# Data(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', employer='Eichmann, Quigley and Macejkovic', department='Business Development', employee_id='48-8059597', last_updated=datetime.datetime(2017, 9, 2, 5, 13, 32), created=datetime.datetime(2016, 2, 23, 16, 20, 59), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995)
# Data(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', employer='Bosco-Kunde', department='Services', employee_id='55-1726090', last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50), vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000)
# Data(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', employer='Ratke-Raynor', department='Legal', employee_id='60-6687797', last_updated=datetime.datetime(2017, 6, 4, 1, 39, 16), created=datetime.datetime(2016, 4, 23, 14, 7, 49), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Data(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', employer='Bergstrom-Boyle', department='Marketing', employee_id='72-3121170', last_updated=datetime.datetime(2018, 2, 8, 11, 16, 12), created=datetime.datetime(2016, 10, 19, 8, 22, 59), vehicle_make='Ford', vehicle_model='Probe', model_year=1996)
# Data(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy', employer='McLaughlin-Rohan', department='Legal', employee_id='47-1922172', last_updated=datetime.datetime(2017, 2, 13, 21, 31, 15), created=datetime.datetime(2016, 4, 28, 8, 28, 43), vehicle_make='Ford', vehicle_model='F250', model_year=1999)
# Data(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id='93-3103060', last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10), vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# Data(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', employer='Little, Hagenes and McKenzie', department='Training', employee_id='75-9906937', last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001)
# Data(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French', employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id='95-5604381', last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39), vehicle_make='Ford', vehicle_model='Taurus', model_year=1998)
# Data(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', employer='Gorczany LLC', department='Training', employee_id='62-8983936', last_updated=datetime.datetime(2017, 4, 19, 22, 8, 24), created=datetime.datetime(2016, 1, 29, 12, 43, 45), vehicle_make='Nissan', vehicle_model='Armada', model_year=2005)
# Data(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', employer='Little, Powlowski and Witting', department='Business Development', employee_id='42-4459617', last_updated=datetime.datetime(2017, 9, 10, 22, 58, 31), created=datetime.datetime(2016, 10, 20, 19, 49, 24), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011)
# Data(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', employer='King LLC', department='Research and Development', employee_id='39-4026042', last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32), vehicle_make='Acura', vehicle_model='TL', model_year=2005)
# Data(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', employer='Konopelski-Vandervort', department='Legal', employee_id='87-8332368', last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29), vehicle_make='Audi', vehicle_model='Q7', model_year=2007)
# Data(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', employer='Reichel Group', department='Training', employee_id='10-5605387', last_updated=datetime.datetime(2017, 3, 24, 8, 58, 33), created=datetime.datetime(2016, 9, 15, 16, 11, 12), vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005)
# Data(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', employer='Gerhold-Marquardt', department='Research and Development', employee_id='25-6013938', last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2), vehicle_make='BMW', vehicle_model='Z3', model_year=1996)
# Data(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', employer='Greenholt-Hermiston', department='Business Development', employee_id='66-9841280', last_updated=datetime.datetime(2017, 7, 3, 6, 26, 41), created=datetime.datetime(2016, 6, 9, 5, 30, 33), vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999)
# Data(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id='83-2548521', last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55), vehicle_make='Ford', vehicle_model='Mustang', model_year=1995)
# Data(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', employer='Roberts Group', department='Product Management', employee_id='07-6620387', last_updated=datetime.datetime(2017, 9, 6, 16, 56, 6), created=datetime.datetime(2016, 10, 23, 1, 47, 51), vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998)
# Data(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', employer='Olson-Lynch', department='Business Development', employee_id='50-7113609', last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33), vehicle_make='Honda', vehicle_model='Civic', model_year=2012)
# Data(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', employer='Quitzon, Rempel and Hane', department='Business Development', employee_id='03-4767523', last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001)
# Data(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', employer='Carroll, Konopelski and Wunsch', department='Research and Development', employee_id='43-4797129', last_updated=datetime.datetime(2017, 8, 14, 16, 48, 43), created=datetime.datetime(2016, 7, 2, 8, 33, 48), vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008)
# Data(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', employer='Howell LLC', department='Business Development', employee_id='70-2399476', last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1), vehicle_make='GMC', vehicle_model='3500', model_year=1998)
# Data(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', employer='Johnson Inc', department='Services', employee_id='34-7741883', last_updated=datetime.datetime(2018, 1, 4, 21, 50, 39), created=datetime.datetime(2016, 1, 29, 15, 31, 40), vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989)
# Data(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', employer='Corwin and Sons', department='Legal', employee_id='15-8160997', last_updated=datetime.datetime(2017, 6, 10, 3, 48, 51), created=datetime.datetime(2016, 9, 27, 15, 4, 24), vehicle_make='Toyota', vehicle_model='MR2', model_year=1993)
# Data(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara', employer='Zemlak LLC', department='Research and Development', employee_id='86-8667896', last_updated=datetime.datetime(2017, 2, 11, 14, 12, 16), created=datetime.datetime(2016, 9, 19, 20, 5, 7), vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012)
# Data(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', employer='Toy-Jakubowski', department='Engineering', employee_id='17-8085199', last_updated=datetime.datetime(2017, 7, 17, 2, 59, 15), created=datetime.datetime(2016, 4, 30, 9, 17, 39), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964)
# Data(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', employer='Murphy, Windler and Bartoletti', department='Legal', employee_id='02-6976472', last_updated=datetime.datetime(2017, 3, 5, 0, 46, 26), created=datetime.datetime(2016, 6, 15, 5, 37, 27), vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010)
# Data(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', employer='Batz Inc', department='Support', employee_id='49-2738721', last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37), vehicle_make='Ford', vehicle_model='Mustang', model_year=1985)
# Data(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', employer='Jast and Sons', department='Services', employee_id='38-6141294', last_updated=datetime.datetime(2018, 3, 2, 23, 30, 36), created=datetime.datetime(2016, 5, 12, 16, 1, 48), vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011)
# Data(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French', employer='Roberts LLC', department='Research and Development', employee_id='91-2028080', last_updated=datetime.datetime(2017, 10, 11, 13, 32, 41), created=datetime.datetime(2016, 9, 10, 9, 18, 50), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Data(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian', employer='Schultz, Price and Walsh', department='Business Development', employee_id='69-6328477', last_updated=datetime.datetime(2017, 1, 25, 2, 11, 6), created=datetime.datetime(2016, 7, 24, 12, 57, 57), vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969)
# Data(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', employer='Zulauf, Hudson and Wisozk', department='Research and Development', employee_id='39-1896194', last_updated=datetime.datetime(2018, 3, 3, 15, 18, 26), created=datetime.datetime(2016, 10, 26, 15, 24, 37), vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# Data(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', employer='Bode-Zulauf', department='Marketing', employee_id='42-0021775', last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59), vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988)
# Data(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz', employer='Windler Group', department='Legal', employee_id='16-2190623', last_updated=datetime.datetime(2017, 1, 25, 11, 34, 25), created=datetime.datetime(2016, 5, 14, 4, 55, 35), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972)
# Data(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati', employer='Jast-Quitzon', department='Human Resources', employee_id='67-5707294', last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25), vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994)
# Data(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian', employer='Green-Waelchi', department='Engineering', employee_id='29-7065788', last_updated=datetime.datetime(2017, 9, 30, 14, 38, 36), created=datetime.datetime(2016, 8, 1, 11, 19, 25), vehicle_make='Ford', vehicle_model='Taurus', model_year=1991)
# Data(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai', employer='Brown Group', department='Accounting', employee_id='91-0435820', last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42), vehicle_make='Toyota', vehicle_model='Celica', model_year=1995)
# Data(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', employer='MacGyver-Hartmann', department='Accounting', employee_id='77-4207310', last_updated=datetime.datetime(2017, 4, 1, 20, 14, 53), created=datetime.datetime(2016, 12, 3, 15, 8, 4), vehicle_make='Jeep', vehicle_model='Commander', model_year=2007)
# Data(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', employer='McGlynn LLC', department='Support', employee_id='35-4393230', last_updated=datetime.datetime(2017, 3, 23, 1, 30, 12), created=datetime.datetime(2016, 3, 6, 13, 15, 20), vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013)
# Data(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', employer='Little, Herzog and Mertz', department='Legal', employee_id='45-9164509', last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19), vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995)
# Data(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', employer='Kertzmann-Reichel', department='Research and Development', employee_id='67-0581933', last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49), vehicle_make='GMC', vehicle_model='Canyon', model_year=2004)
# Data(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', employer='Douglas, Funk and Schowalter', department='Services', employee_id='77-2512148', last_updated=datetime.datetime(2017, 8, 16, 21, 35, 50), created=datetime.datetime(2016, 9, 15, 10, 22, 56), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008)
# Data(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', employer='Bayer-Kunze', department='Support', employee_id='86-6996270', last_updated=datetime.datetime(2017, 10, 2, 6, 22, 27), created=datetime.datetime(2016, 10, 16, 12, 16, 53), vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988)
# Data(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', employer='Kiehn, Hansen and Will', department='Support', employee_id='94-8005696', last_updated=datetime.datetime(2017, 7, 5, 10, 19, 41), created=datetime.datetime(2016, 7, 23, 3, 16, 13), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997)
# Data(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian', employer='Kling-Howe', department='Research and Development', employee_id='71-7470887', last_updated=datetime.datetime(2017, 11, 3, 0, 36, 20), created=datetime.datetime(2016, 9, 8, 5, 10, 46), vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991)
# Data(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', employer='Quitzon-Morissette', department='Product Management', employee_id='81-5434446', last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46), vehicle_make='Ford', vehicle_model='Mustang', model_year=1998)
# Data(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', employer='Bergstrom-Daniel', department='Marketing', employee_id='31-7381298', last_updated=datetime.datetime(2017, 10, 15, 21, 11, 17), created=datetime.datetime(2016, 11, 17, 18, 52, 56), vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997)
# Data(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', employer='Johnston, Leuschke and Stracke', department='Support', employee_id='96-9321837', last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30), vehicle_make='Scion', vehicle_model='xD', model_year=2011)
# Data(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', employer='Lubowitz-Franecki', department='Product Management', employee_id='68-5287750', last_updated=datetime.datetime(2017, 3, 28, 16, 56, 35), created=datetime.datetime(2016, 6, 3, 5, 38, 20), vehicle_make='Audi', vehicle_model='90', model_year=1991)
# Data(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua', employer='Nienow-Metz', department='Legal', employee_id='88-5601438', last_updated=datetime.datetime(2017, 2, 19, 15, 12, 50), created=datetime.datetime(2016, 10, 24, 14, 3, 4), vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998)
# Data(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', employer='Quitzon, Stiedemann and Breitenberg', department='Services', employee_id='76-1399493', last_updated=datetime.datetime(2017, 7, 1, 13, 56, 28), created=datetime.datetime(2016, 8, 8, 8, 4, 45), vehicle_make='Mercury', vehicle_model='Sable', model_year=2001)
# Data(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', employer='Turner-Connelly', department='Research and Development', employee_id='92-1687621', last_updated=datetime.datetime(2017, 6, 9, 12, 34, 32), created=datetime.datetime(2016, 9, 17, 22, 55, 15), vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990)
# Data(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', employer='Kling, Prosacco and Wisoky', department='Accounting', employee_id='77-0491080', last_updated=datetime.datetime(2017, 12, 26, 5, 29, 23), created=datetime.datetime(2016, 6, 5, 4, 26, 52), vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003)
# Data(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', employer="Von, O'Kon and Runolfsdottir", department='Research and Development', employee_id='34-6414700', last_updated=datetime.datetime(2017, 12, 27, 3, 41, 46), created=datetime.datetime(2016, 6, 30, 2, 48, 10), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985)
# Data(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', employer='McLaughlin-Botsford', department='Business Development', employee_id='60-2450272', last_updated=datetime.datetime(2017, 8, 8, 19, 29, 59), created=datetime.datetime(2016, 9, 9, 19, 38, 18), vehicle_make='BMW', vehicle_model='8 Series', model_year=1995)
# Data(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua', employer='Mann-Stehr', department='Sales', employee_id='82-9383132', last_updated=datetime.datetime(2017, 2, 12, 16, 15, 44), created=datetime.datetime(2016, 6, 21, 4, 10, 57), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Data(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', employer='Smitham-Blick', department='Engineering', employee_id='07-3918459', last_updated=datetime.datetime(2017, 6, 6, 20, 51, 23), created=datetime.datetime(2016, 2, 17, 12, 0, 16), vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990)
# Data(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', employer='Reilly and Sons', department='Product Management', employee_id='00-2155545', last_updated=datetime.datetime(2018, 2, 12, 20, 26, 30), created=datetime.datetime(2016, 4, 15, 16, 42, 18), vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993)
# Data(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', employer='Keeling, Hansen and Mertz', department='Training', employee_id='86-3420084', last_updated=datetime.datetime(2017, 7, 27, 9, 14, 42), created=datetime.datetime(2016, 5, 23, 13, 52, 39), vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009)
# Data(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', employer='Mante Inc', department='Business Development', employee_id='39-8018810', last_updated=datetime.datetime(2017, 3, 18, 6, 5, 59), created=datetime.datetime(2016, 11, 16, 1, 58, 55), vehicle_make='Volvo', vehicle_model='C70', model_year=1998)
# Data(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew', employer='Nicolas Group', department='Support', employee_id='75-2636577', last_updated=datetime.datetime(2017, 1, 19, 20, 59, 49), created=datetime.datetime(2016, 6, 13, 1, 23, 53), vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999)
# Data(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', employer='Sauer, Mann and Kling', department='Accounting', employee_id='89-3029716', last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001)
# Data(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id='29-2776451', last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3), vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007)
# Data(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya', employer='Prosacco LLC', department='Business Development', employee_id='53-6059808', last_updated=datetime.datetime(2017, 1, 23, 2, 41, 20), created=datetime.datetime(2016, 8, 1, 21, 34, 6), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007)
# Data(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian', employer='Mante, Roberts and Miller', department='Research and Development', employee_id='98-1318396', last_updated=datetime.datetime(2017, 2, 13, 7, 16, 31), created=datetime.datetime(2016, 1, 22, 5, 10, 14), vehicle_make='Infiniti', vehicle_model='QX', model_year=2005)
# Data(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', employer='Farrell and Sons', department='Product Management', employee_id='85-3648779', last_updated=datetime.datetime(2017, 6, 23, 12, 59, 20), created=datetime.datetime(2016, 11, 7, 0, 25, 12), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003)
# Data(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', employer='Heathcote-Torp', department='Product Management', employee_id='77-2681193', last_updated=datetime.datetime(2018, 2, 23, 10, 14, 54), created=datetime.datetime(2016, 4, 5, 5, 11, 13), vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006)
# ...
# Data(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', employer='Reinger Inc', department='Engineering', employee_id='80-2005731', last_updated=datetime.datetime(2017, 4, 15, 11, 12, 57), created=datetime.datetime(2016, 6, 22, 23, 23, 9), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007)
# Data(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', employer='Stokes Inc', department='Training', employee_id='12-6635955', last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34), vehicle_make='BMW', vehicle_model='M5', model_year=2007)
# Data(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', employer='Dicki, Green and White', department='Services', employee_id='87-1017676', last_updated=datetime.datetime(2017, 5, 3, 14, 37, 42), created=datetime.datetime(2016, 2, 4, 14, 11, 40), vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002)
# Data(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian', employer='Thiel, Parker and Hilpert', department='Marketing', employee_id='20-2324966', last_updated=datetime.datetime(2017, 2, 4, 13, 53, 10), created=datetime.datetime(2016, 12, 28, 0, 33, 8), vehicle_make='Acura', vehicle_model='ZDX', model_year=2011)
# Data(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama', employer='Heidenreich, Stehr and Huel', department='Sales', employee_id='89-1713880', last_updated=datetime.datetime(2017, 2, 3, 17, 51, 18), created=datetime.datetime(2016, 2, 14, 3, 7, 23), vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004)
# Data(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', employer='Bartoletti Inc', department='Support', employee_id='77-7239839', last_updated=datetime.datetime(2017, 5, 31, 4, 28, 19), created=datetime.datetime(2016, 2, 2, 17, 47, 22), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Data(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', employer='Douglas-Breitenberg', department='Business Development', employee_id='63-6285198', last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20), vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997)
# Data(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', employer='Nitzsche-Walker', department='Engineering', employee_id='50-5681388', last_updated=datetime.datetime(2018, 1, 25, 4, 2, 4), created=datetime.datetime(2016, 10, 31, 14, 12, 16), vehicle_make='Volvo', vehicle_model='S80', model_year=2001)
# Data(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', employer='Crist, Leuschke and Grimes', department='Legal', employee_id='09-8398802', last_updated=datetime.datetime(2017, 10, 31, 17, 48, 23), created=datetime.datetime(2016, 7, 17, 9, 50, 7), vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986)
# Data(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', employer='Emard Inc', department='Business Development', employee_id='49-2589434', last_updated=datetime.datetime(2018, 3, 11, 16, 42, 31), created=datetime.datetime(2016, 11, 4, 18, 34, 52), vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# Data(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', employer='Abshire Inc', department='Research and Development', employee_id='55-8987515', last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007)
# Data(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana', employer='Thompson, Parker and Moen', department='Research and Development', employee_id='46-1484106', last_updated=datetime.datetime(2017, 1, 19, 3, 43, 35), created=datetime.datetime(2016, 6, 24, 16, 43, 15), vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991)
# Data(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', employer='Morissette, Rowe and Muller', department='Engineering', employee_id='73-9912953', last_updated=datetime.datetime(2017, 3, 3, 3, 45, 30), created=datetime.datetime(2016, 6, 21, 17, 1, 53), vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998)
# Data(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id='16-1937114', last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26), vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000)
# Data(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', employer='Glover, Jacobs and Heidenreich', department='Sales', employee_id='72-1577952', last_updated=datetime.datetime(2018, 3, 22, 21, 11, 58), created=datetime.datetime(2016, 4, 27, 3, 27, 17), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Data(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', employer='Cummings-Mertz', department='Sales', employee_id='78-2291834', last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19), vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# Data(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', employer='Wilderman-Grimes', department='Engineering', employee_id='39-6055619', last_updated=datetime.datetime(2017, 7, 23, 1, 30, 5), created=datetime.datetime(2016, 7, 8, 7, 10, 52), vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964)
# Data(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', employer='Schultz-Medhurst', department='Support', employee_id='56-6050344', last_updated=datetime.datetime(2017, 3, 14, 4, 45, 19), created=datetime.datetime(2016, 8, 19, 18, 23, 57), vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993)
# Data(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', employer='Wunsch-Gleason', department='Services', employee_id='28-3015726', last_updated=datetime.datetime(2017, 12, 3, 21, 27, 47), created=datetime.datetime(2016, 6, 12, 12, 36, 44), vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000)
# Data(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', employer='Witting, Schuster and Barton', department='Research and Development', employee_id='54-4161357', last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37), vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998)
# Data(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri', employer='Harber-Legros', department='Training', employee_id='59-9280036', last_updated=datetime.datetime(2017, 1, 13, 19, 50, 26), created=datetime.datetime(2016, 6, 11, 20, 35, 38), vehicle_make='Toyota', vehicle_model='Camry', model_year=2008)
# Data(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', employer='Daugherty, Gislason and Kreiger', department='Training', employee_id='25-5973403', last_updated=datetime.datetime(2018, 2, 4, 17, 29, 28), created=datetime.datetime(2016, 10, 5, 21, 57, 12), vehicle_make='Infiniti', vehicle_model='G', model_year=2004)
# Data(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', employer="O'Connell, Raynor and Veum", department='Sales', employee_id='16-0843654', last_updated=datetime.datetime(2017, 8, 11, 11, 40, 28), created=datetime.datetime(2016, 1, 18, 12, 51), vehicle_make='Subaru', vehicle_model='SVX', model_year=1994)
# Data(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', employer='Schumm Inc', department='Services', employee_id='18-8360445', last_updated=datetime.datetime(2018, 1, 29, 16, 6, 26), created=datetime.datetime(2016, 11, 24, 12, 12, 51), vehicle_make='BMW', vehicle_model='M6', model_year=2009)
# Data(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian', employer='Zulauf Inc', department='Accounting', employee_id='46-7067366', last_updated=datetime.datetime(2017, 2, 10, 19, 26, 8), created=datetime.datetime(2016, 8, 27, 5, 43, 5), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Data(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian', employer='Stanton, Price and Wehner', department='Services', employee_id='16-5769119', last_updated=datetime.datetime(2017, 1, 9, 19, 30, 49), created=datetime.datetime(2016, 3, 18, 22, 13, 6), vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996)
# Data(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id='71-6097002', last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53), vehicle_make='Lexus', vehicle_model='GS', model_year=2013)
# Data(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', employer='Terry and Sons', department='Research and Development', employee_id='06-9390159', last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28), vehicle_make='Audi', vehicle_model='S6', model_year=2011)
# Data(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', employer='Herzog, Stehr and Quitzon', department='Engineering', employee_id='38-5385705', last_updated=datetime.datetime(2018, 3, 6, 16, 54, 20), created=datetime.datetime(2016, 6, 9, 11, 3, 40), vehicle_make='Nissan', vehicle_model='Armada', model_year=2008)
# Data(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', employer='Collier, Hilll and Hagenes', department='Training', employee_id='15-6651242', last_updated=datetime.datetime(2017, 9, 5, 0, 30), created=datetime.datetime(2016, 2, 12, 1, 35, 59), vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991)
# Data(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id='48-3998718', last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16), vehicle_make='Volvo', vehicle_model='S60', model_year=2005)
# Data(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', employer='Heller, Kihn and Bartoletti', department='Research and Development', employee_id='56-9393666', last_updated=datetime.datetime(2018, 1, 6, 9, 34, 59), created=datetime.datetime(2016, 2, 22, 15, 24, 59), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000)
# Data(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', employer='Christiansen LLC', department='Sales', employee_id='66-1175841', last_updated=datetime.datetime(2018, 3, 27, 1, 24, 58), created=datetime.datetime(2016, 6, 14, 2, 41, 25), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991)
# Data(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', employer='Orn Inc', department='Human Resources', employee_id='38-4356300', last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12), vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# Data(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', employer='Flatley, Senger and Bernier', department='Services', employee_id='72-2633200', last_updated=datetime.datetime(2017, 3, 7, 4, 8, 28), created=datetime.datetime(2016, 7, 9, 11, 43, 17), vehicle_make='Kia', vehicle_model='Sedona', model_year=2012)
# Data(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', employer='Hilll, Kunze and Beer', department='Human Resources', employee_id='90-4168298', last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003)
# Data(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', employer='Franecki LLC', department='Services', employee_id='63-7802530', last_updated=datetime.datetime(2017, 5, 13, 5, 52, 27), created=datetime.datetime(2016, 3, 24, 7, 34, 14), vehicle_make='Acura', vehicle_model='TL', model_year=1999)
# Data(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', employer='Reilly-Jakubowski', department='Marketing', employee_id='77-6363112', last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48), vehicle_make='BMW', vehicle_model='X3', model_year=2011)
# Data(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', employer='Bins-Gerhold', department='Sales', employee_id='89-9965641', last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2), vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994)
# Data(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', employer='Olson-Johnson', department='Support', employee_id='36-7761827', last_updated=datetime.datetime(2017, 7, 3, 14, 27, 26), created=datetime.datetime(2016, 11, 23, 23, 34, 17), vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003)
# Data(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', employer='Cronin LLC', department='Services', employee_id='83-8730953', last_updated=datetime.datetime(2017, 7, 31, 2, 26, 57), created=datetime.datetime(2016, 10, 27, 18, 41, 56), vehicle_make='Toyota', vehicle_model='Camry', model_year=2012)
# Data(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', employer='Little-Hansen', department='Business Development', employee_id='45-8154226', last_updated=datetime.datetime(2017, 8, 2, 13, 32, 33), created=datetime.datetime(2016, 7, 27, 12, 47, 5), vehicle_make='Infiniti', vehicle_model='FX', model_year=2006)
# Data(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id='32-7034344', last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999)
# Data(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', employer='Bednar LLC', department='Support', employee_id='16-6342889', last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23), vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)

# %% [markdown]
# ### GOAL - 3

# %%
from collections import namedtuple
from csv import reader
from datetime import datetime

HEADER = []

def generate(file_name: str):
    def create_tuple(iterator):
        header = next(iterator)
        HEADER.append(header)
        return namedtuple('Data', header)

    def convert(row, mode):
        if mode == 'update_status.csv':
            format = '%Y-%m-%dT%H:%M:%SZ'
            row[1], row[2] = datetime.strptime(row[1], format), datetime.strptime(row[2], format)

        elif mode == 'vehicles.csv':
            row[-1] = int(row[-1])

    with open(file_name) as f:
        data = reader(f, lineterminator='\n')
        Data = create_tuple(data)

        for row in data:
            convert(row, file_name)
            yield Data(*row)

def all_data():
    def create_tuple(header):
        values = []

        for head in header:
            for value in head:
                if value not in values:
                    values.append(value)

        return namedtuple('Data', values)

    gen_lst = [generate(file)
               for file in ('personal_info.csv', 'employment.csv', 'update_status.csv', 'vehicles.csv')]
    iter1, iter2, iter3, iter4 = gen_lst
    _ = next(iter1), next(iter2), next(iter3), next(iter4)
    Data = create_tuple(HEADER)

    while True:
        try:
            data1, data2, data3, data4 = next(iter1), next(iter2), next(iter3), next(iter4)
            all_data = data1 + data2[:-1] + data3[1:] + data4[1:]
            yield Data(*all_data)

        except StopIteration:
            break

def filter_data():
    data = all_data()
    return filter(lambda row: row.last_updated >= datetime(2017, 1, 3, 0, 0, 0), data)

# %%
for i in filter_data():
    print(i)
# Out:
# Data(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', employer='Nicolas and Sons', department='Sales', employee_id='41-6841359', last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57), vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# Data(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', employer='Connelly Group', department='Research and Development', employee_id='98-7952860', last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7), vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# Data(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', employer='Upton LLC', department='Marketing', employee_id='56-9817552', last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17), vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# Data(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', employer='Zemlak-Olson', department='Business Development', employee_id='46-2886707', last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57), vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)
# Data(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', employer='Kohler, Bradtke and Davis', department='Support', employee_id='80-0975518', last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35), vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# Data(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', employer='Roberts, Torphy and Dach', department='Human Resources', employee_id='77-4895332', last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43), vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# Data(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', employer='Lind-Jast', department='Marketing', employee_id='79-6418731', last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3), vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000)
# Data(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian', employer='Bashirian-Lueilwitz', department='Engineering', employee_id='44-3328799', last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13), vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# Data(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', employer='Windler, Marks and Haley', department='Services', employee_id='54-6271885', last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12), vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992)
# Data(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', employer='Leffler-Hahn', department='Accounting', employee_id='31-5735282', last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Data(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', employer='Lueilwitz LLC', department='Marketing', employee_id='33-9146042', last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5), vehicle_make='Ford', vehicle_model='Mustang', model_year=1990)
# Data(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', employer='Davis Inc', department='Accounting', employee_id='39-0400385', last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17), vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# Data(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch', employer='Kunze LLC', department='Research and Development', employee_id='78-2612900', last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3), vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011)
# Data(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', employer='Mayert, Rice and Schmitt', department='Product Management', employee_id='85-8596488', last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25), vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# Data(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', employer='Pouros LLC', department='Legal', employee_id='14-2589283', last_updated=datetime.datetime(2017, 10, 30, 23, 54, 38), created=datetime.datetime(2016, 6, 4, 5, 18, 3), vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009)
# Data(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', employer='Pfannerstill Group', department='Research and Development', employee_id='43-1532437', last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26), vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009)
# Data(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian', employer='Ryan Group', department='Sales', employee_id='08-8274517', last_updated=datetime.datetime(2017, 11, 21, 14, 25, 11), created=datetime.datetime(2016, 7, 3, 3, 55, 39), vehicle_make='Buick', vehicle_model='Rainier', model_year=2004)
# Data(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', employer='Ritchie-Pagac', department='Business Development', employee_id='38-0095184', last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17), vehicle_make='Scion', vehicle_model='tC', model_year=2008)
# Data(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew', employer='Schmeler and Sons', department='Research and Development', employee_id='62-3275199', last_updated=datetime.datetime(2017, 2, 18, 23, 9, 25), created=datetime.datetime(2016, 2, 2, 15, 41, 42), vehicle_make='Audi', vehicle_model='S6', model_year=2009)
# Data(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', employer='Kerluke-Dibbert', department='Services', employee_id='90-5121197', last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1), vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007)
# Data(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', employer='Hane-Klocko', department='Human Resources', employee_id='27-2946273', last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992)
# Data(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', employer='Ernser LLC', department='Services', employee_id='07-6466085', last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Data(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', employer='Terry LLC', department='Accounting', employee_id='70-4864087', last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005)
# Data(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', employer='Rolfson, Price and Crooks', department='Business Development', employee_id='77-0255816', last_updated=datetime.datetime(2017, 11, 11, 8, 53, 11), created=datetime.datetime(2016, 7, 10, 20, 49), vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997)
# Data(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', employer='Romaguera, Welch and Haley', department='Engineering', employee_id='14-6523887', last_updated=datetime.datetime(2017, 12, 1, 17, 30, 55), created=datetime.datetime(2016, 7, 23, 15, 52, 53), vehicle_make='Acura', vehicle_model='RL', model_year=2003)
# Data(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', employer='Paucek, Huels and Bauch', department='Accounting', employee_id='21-1452824', last_updated=datetime.datetime(2017, 8, 23, 16, 0, 57), created=datetime.datetime(2016, 6, 26, 23, 46, 48), vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002)
# Data(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', employer='Hayes-Trantow', department='Support', employee_id='07-2855255', last_updated=datetime.datetime(2017, 8, 16, 12, 8, 6), created=datetime.datetime(2016, 10, 23, 13, 32, 13), vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# Data(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id='57-1590433', last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5), vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999)
# Data(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', employer='Mueller-Rath', department='Human Resources', employee_id='05-8069298', last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36), vehicle_make='Ford', vehicle_model='Mustang', model_year=1989)
# Data(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian', employer='Schumm, Schumm and Reichert', department='Engineering', employee_id='73-3839744', last_updated=datetime.datetime(2017, 2, 7, 14, 36, 31), created=datetime.datetime(2016, 7, 8, 17, 46, 23), vehicle_make='Lexus', vehicle_model='RX', model_year=2010)
# Data(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', employer='Tromp-Leffler', department='Support', employee_id='02-6267170', last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004)
# Data(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara', employer='Wolf LLC', department='Engineering', employee_id='53-8370994', last_updated=datetime.datetime(2017, 1, 12, 9, 42, 31), created=datetime.datetime(2016, 10, 9, 1, 14, 36), vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008)
# Data(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', employer='Kulas-Corwin', department='Sales', employee_id='78-0632027', last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21), vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# Data(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', employer='MacGyver, Wiegand and Grant', department='Product Management', employee_id='77-4182531', last_updated=datetime.datetime(2017, 9, 10, 6, 24, 19), created=datetime.datetime(2016, 7, 23, 1, 30, 3), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007)
# Data(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian', employer="Kertzmann-O'Hara", department='Sales', employee_id='44-8015165', last_updated=datetime.datetime(2017, 1, 29, 20, 31, 15), created=datetime.datetime(2016, 7, 13, 9, 52, 36), vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006)
# Data(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', employer='Vandervort, Bernier and Morissette', department='Human Resources', employee_id='14-4998615', last_updated=datetime.datetime(2017, 8, 10, 21, 18), created=datetime.datetime(2016, 12, 19, 21, 37, 6), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Data(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', employer='King-Donnelly', department='Training', employee_id='82-0573004', last_updated=datetime.datetime(2017, 8, 31, 16, 42, 23), created=datetime.datetime(2016, 7, 29, 3, 46, 26), vehicle_make='Dodge', vehicle_model='Neon', model_year=1995)
# Data(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', employer='Harris Inc', department='Support', employee_id='53-7535536', last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56), vehicle_make='BMW', vehicle_model='M', model_year=2001)
# Data(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech', employer='Heidenreich, Bergnaum and Smith', department='Training', employee_id='04-7204163', last_updated=datetime.datetime(2017, 1, 3, 20, 33, 45), created=datetime.datetime(2016, 3, 18, 11, 18, 14), vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988)
# Data(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha', employer='Altenwerth-Heidenreich', department='Research and Development', employee_id='58-3628686', last_updated=datetime.datetime(2017, 2, 11, 10, 18, 21), created=datetime.datetime(2016, 12, 12, 5, 1, 34), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993)
# Data(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', employer='Gibson and Sons', department='Sales', employee_id='57-8173633', last_updated=datetime.datetime(2018, 3, 21, 12, 2, 31), created=datetime.datetime(2016, 2, 3, 23, 26, 27), vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012)
# Data(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi', employer='Rodriguez LLC', department='Legal', employee_id='65-7310166', last_updated=datetime.datetime(2017, 1, 19, 7, 33, 37), created=datetime.datetime(2016, 5, 20, 1, 41, 54), vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992)
# Data(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', employer='Donnelly-Crooks', department='Human Resources', employee_id='22-2943669', last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40), vehicle_make='BMW', vehicle_model='M5', model_year=2006)
# Data(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', employer='Hyatt LLC', department='Training', employee_id='96-9647102', last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17), vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004)
# Data(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', employer='Schuster Group', department='Research and Development', employee_id='72-4728604', last_updated=datetime.datetime(2017, 12, 24, 9, 44, 10), created=datetime.datetime(2016, 3, 1, 19, 9, 29), vehicle_make='Infiniti', vehicle_model='G', model_year=2005)
# Data(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', employer='Homenick-Beer', department='Product Management', employee_id='01-9334133', last_updated=datetime.datetime(2017, 4, 17, 16, 30, 2), created=datetime.datetime(2016, 12, 17, 7, 7, 47), vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992)
# Data(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', employer='VonRueden-Torphy', department='Business Development', employee_id='10-6636122', last_updated=datetime.datetime(2018, 3, 4, 8, 14, 31), created=datetime.datetime(2016, 9, 24, 1, 52, 46), vehicle_make='Lexus', vehicle_model='RX', model_year=2003)
# Data(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese', employer='Mohr, Harvey and Mitchell', department='Legal', employee_id='64-7550101', last_updated=datetime.datetime(2017, 2, 24, 15, 47, 36), created=datetime.datetime(2016, 1, 4, 9, 37, 53), vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004)
# Data(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian', employer='Keeling-Schroeder', department='Engineering', employee_id='82-2479019', last_updated=datetime.datetime(2017, 2, 16, 21, 23, 10), created=datetime.datetime(2016, 5, 24, 4, 10, 50), vehicle_make='Ford', vehicle_model='Escort', model_year=1997)
# Data(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', employer='Gusikowski-Block', department='Legal', employee_id='41-1454732', last_updated=datetime.datetime(2017, 8, 19, 16, 22, 52), created=datetime.datetime(2016, 9, 10, 21, 9, 28), vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990)
# Data(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', employer='Pollich-Heathcote', department='Product Management', employee_id='12-2844710', last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20), vehicle_make='Volvo', vehicle_model='V70', model_year=2002)
# Data(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', employer='Bogisich Inc', department='Human Resources', employee_id='34-7172919', last_updated=datetime.datetime(2017, 9, 21, 23, 4, 48), created=datetime.datetime(2016, 1, 27, 9, 2, 26), vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# Data(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori', employer='Gutkowski Inc', department='Engineering', employee_id='83-4836768', last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22), vehicle_make='Volvo', vehicle_model='XC90', model_year=2009)
# Data(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', employer='Greenholt LLC', department='Sales', employee_id='84-5391800', last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37), vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000)
# Data(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', employer='Hartmann Inc', department='Support', employee_id='26-7276512', last_updated=datetime.datetime(2018, 1, 24, 20, 0, 4), created=datetime.datetime(2016, 12, 20, 0, 43, 43), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Data(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', employer='Zboncak-Gulgowski', department='Marketing', employee_id='05-0368584', last_updated=datetime.datetime(2017, 7, 16, 15, 12, 37), created=datetime.datetime(2016, 7, 30, 13, 28, 38), vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999)
# Data(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', employer='Altenwerth-Emard', department='Marketing', employee_id='30-5847411', last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005)
# Data(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', employer='Cronin Inc', department='Business Development', employee_id='08-3106397', last_updated=datetime.datetime(2017, 7, 21, 18, 54, 47), created=datetime.datetime(2016, 2, 9, 6, 10, 21), vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# Data(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese', employer='Murray, Wolff and Little', department='Business Development', employee_id='29-3578815', last_updated=datetime.datetime(2017, 1, 18, 6, 37, 31), created=datetime.datetime(2016, 4, 25, 21, 45), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Data(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', employer='Dibbert LLC', department='Support', employee_id='09-9620598', last_updated=datetime.datetime(2018, 2, 20, 12, 47, 43), created=datetime.datetime(2016, 10, 3, 5, 18, 6), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Data(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', employer='Tromp Inc', department='Research and Development', employee_id='06-3360383', last_updated=datetime.datetime(2017, 6, 10, 6, 21, 46), created=datetime.datetime(2016, 9, 23, 15, 35, 52), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993)
# Data(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', employer='Kub, Koch and Ratke', department='Marketing', employee_id='72-7830449', last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988)
# Data(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', employer='Greenholt-Gusikowski', department='Engineering', employee_id='16-6006875', last_updated=datetime.datetime(2018, 2, 9, 4, 41, 58), created=datetime.datetime(2016, 5, 31, 23, 38, 59), vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995)
# Data(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', employer='Tremblay, Jacobs and Swift', department='Training', employee_id='46-1648855', last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36), vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996)
# Data(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', employer='Bashirian-Moen', department='Training', employee_id='51-9115041', last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52), vehicle_make='Ford', vehicle_model='Explorer', model_year=2005)
# Data(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', employer='Hudson-Gerhold', department='Human Resources', employee_id='62-2244500', last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29), vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992)
# Data(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', employer='Balistreri Inc', department='Sales', employee_id='92-8183627', last_updated=datetime.datetime(2017, 8, 31, 2, 41, 41), created=datetime.datetime(2016, 10, 21, 12, 17, 57), vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992)
# Data(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', employer='Eichmann, Quigley and Macejkovic', department='Business Development', employee_id='48-8059597', last_updated=datetime.datetime(2017, 9, 2, 5, 13, 32), created=datetime.datetime(2016, 2, 23, 16, 20, 59), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995)
# Data(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', employer='Bosco-Kunde', department='Services', employee_id='55-1726090', last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50), vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000)
# Data(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', employer='Ratke-Raynor', department='Legal', employee_id='60-6687797', last_updated=datetime.datetime(2017, 6, 4, 1, 39, 16), created=datetime.datetime(2016, 4, 23, 14, 7, 49), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Data(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', employer='Bergstrom-Boyle', department='Marketing', employee_id='72-3121170', last_updated=datetime.datetime(2018, 2, 8, 11, 16, 12), created=datetime.datetime(2016, 10, 19, 8, 22, 59), vehicle_make='Ford', vehicle_model='Probe', model_year=1996)
# Data(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy', employer='McLaughlin-Rohan', department='Legal', employee_id='47-1922172', last_updated=datetime.datetime(2017, 2, 13, 21, 31, 15), created=datetime.datetime(2016, 4, 28, 8, 28, 43), vehicle_make='Ford', vehicle_model='F250', model_year=1999)
# Data(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id='93-3103060', last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10), vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# Data(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', employer='Little, Hagenes and McKenzie', department='Training', employee_id='75-9906937', last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001)
# Data(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French', employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id='95-5604381', last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39), vehicle_make='Ford', vehicle_model='Taurus', model_year=1998)
# Data(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', employer='Gorczany LLC', department='Training', employee_id='62-8983936', last_updated=datetime.datetime(2017, 4, 19, 22, 8, 24), created=datetime.datetime(2016, 1, 29, 12, 43, 45), vehicle_make='Nissan', vehicle_model='Armada', model_year=2005)
# Data(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', employer='Little, Powlowski and Witting', department='Business Development', employee_id='42-4459617', last_updated=datetime.datetime(2017, 9, 10, 22, 58, 31), created=datetime.datetime(2016, 10, 20, 19, 49, 24), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011)
# Data(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', employer='King LLC', department='Research and Development', employee_id='39-4026042', last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32), vehicle_make='Acura', vehicle_model='TL', model_year=2005)
# Data(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', employer='Konopelski-Vandervort', department='Legal', employee_id='87-8332368', last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29), vehicle_make='Audi', vehicle_model='Q7', model_year=2007)
# Data(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', employer='Reichel Group', department='Training', employee_id='10-5605387', last_updated=datetime.datetime(2017, 3, 24, 8, 58, 33), created=datetime.datetime(2016, 9, 15, 16, 11, 12), vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005)
# Data(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', employer='Gerhold-Marquardt', department='Research and Development', employee_id='25-6013938', last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2), vehicle_make='BMW', vehicle_model='Z3', model_year=1996)
# Data(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', employer='Greenholt-Hermiston', department='Business Development', employee_id='66-9841280', last_updated=datetime.datetime(2017, 7, 3, 6, 26, 41), created=datetime.datetime(2016, 6, 9, 5, 30, 33), vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999)
# Data(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id='83-2548521', last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55), vehicle_make='Ford', vehicle_model='Mustang', model_year=1995)
# Data(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', employer='Roberts Group', department='Product Management', employee_id='07-6620387', last_updated=datetime.datetime(2017, 9, 6, 16, 56, 6), created=datetime.datetime(2016, 10, 23, 1, 47, 51), vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998)
# Data(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', employer='Olson-Lynch', department='Business Development', employee_id='50-7113609', last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33), vehicle_make='Honda', vehicle_model='Civic', model_year=2012)
# Data(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', employer='Quitzon, Rempel and Hane', department='Business Development', employee_id='03-4767523', last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001)
# Data(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', employer='Carroll, Konopelski and Wunsch', department='Research and Development', employee_id='43-4797129', last_updated=datetime.datetime(2017, 8, 14, 16, 48, 43), created=datetime.datetime(2016, 7, 2, 8, 33, 48), vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008)
# Data(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', employer='Howell LLC', department='Business Development', employee_id='70-2399476', last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1), vehicle_make='GMC', vehicle_model='3500', model_year=1998)
# Data(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', employer='Johnson Inc', department='Services', employee_id='34-7741883', last_updated=datetime.datetime(2018, 1, 4, 21, 50, 39), created=datetime.datetime(2016, 1, 29, 15, 31, 40), vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989)
# Data(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', employer='Corwin and Sons', department='Legal', employee_id='15-8160997', last_updated=datetime.datetime(2017, 6, 10, 3, 48, 51), created=datetime.datetime(2016, 9, 27, 15, 4, 24), vehicle_make='Toyota', vehicle_model='MR2', model_year=1993)
# Data(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara', employer='Zemlak LLC', department='Research and Development', employee_id='86-8667896', last_updated=datetime.datetime(2017, 2, 11, 14, 12, 16), created=datetime.datetime(2016, 9, 19, 20, 5, 7), vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012)
# Data(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', employer='Toy-Jakubowski', department='Engineering', employee_id='17-8085199', last_updated=datetime.datetime(2017, 7, 17, 2, 59, 15), created=datetime.datetime(2016, 4, 30, 9, 17, 39), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964)
# Data(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', employer='Murphy, Windler and Bartoletti', department='Legal', employee_id='02-6976472', last_updated=datetime.datetime(2017, 3, 5, 0, 46, 26), created=datetime.datetime(2016, 6, 15, 5, 37, 27), vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010)
# Data(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', employer='Batz Inc', department='Support', employee_id='49-2738721', last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37), vehicle_make='Ford', vehicle_model='Mustang', model_year=1985)
# Data(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', employer='Jast and Sons', department='Services', employee_id='38-6141294', last_updated=datetime.datetime(2018, 3, 2, 23, 30, 36), created=datetime.datetime(2016, 5, 12, 16, 1, 48), vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011)
# Data(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French', employer='Roberts LLC', department='Research and Development', employee_id='91-2028080', last_updated=datetime.datetime(2017, 10, 11, 13, 32, 41), created=datetime.datetime(2016, 9, 10, 9, 18, 50), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Data(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian', employer='Schultz, Price and Walsh', department='Business Development', employee_id='69-6328477', last_updated=datetime.datetime(2017, 1, 25, 2, 11, 6), created=datetime.datetime(2016, 7, 24, 12, 57, 57), vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969)
# Data(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', employer='Zulauf, Hudson and Wisozk', department='Research and Development', employee_id='39-1896194', last_updated=datetime.datetime(2018, 3, 3, 15, 18, 26), created=datetime.datetime(2016, 10, 26, 15, 24, 37), vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# Data(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', employer='Bode-Zulauf', department='Marketing', employee_id='42-0021775', last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59), vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988)
# Data(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz', employer='Windler Group', department='Legal', employee_id='16-2190623', last_updated=datetime.datetime(2017, 1, 25, 11, 34, 25), created=datetime.datetime(2016, 5, 14, 4, 55, 35), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972)
# Data(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati', employer='Jast-Quitzon', department='Human Resources', employee_id='67-5707294', last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25), vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994)
# Data(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian', employer='Green-Waelchi', department='Engineering', employee_id='29-7065788', last_updated=datetime.datetime(2017, 9, 30, 14, 38, 36), created=datetime.datetime(2016, 8, 1, 11, 19, 25), vehicle_make='Ford', vehicle_model='Taurus', model_year=1991)
# Data(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai', employer='Brown Group', department='Accounting', employee_id='91-0435820', last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42), vehicle_make='Toyota', vehicle_model='Celica', model_year=1995)
# Data(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', employer='MacGyver-Hartmann', department='Accounting', employee_id='77-4207310', last_updated=datetime.datetime(2017, 4, 1, 20, 14, 53), created=datetime.datetime(2016, 12, 3, 15, 8, 4), vehicle_make='Jeep', vehicle_model='Commander', model_year=2007)
# Data(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', employer='McGlynn LLC', department='Support', employee_id='35-4393230', last_updated=datetime.datetime(2017, 3, 23, 1, 30, 12), created=datetime.datetime(2016, 3, 6, 13, 15, 20), vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013)
# Data(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', employer='Little, Herzog and Mertz', department='Legal', employee_id='45-9164509', last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19), vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995)
# Data(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', employer='Kertzmann-Reichel', department='Research and Development', employee_id='67-0581933', last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49), vehicle_make='GMC', vehicle_model='Canyon', model_year=2004)
# Data(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', employer='Douglas, Funk and Schowalter', department='Services', employee_id='77-2512148', last_updated=datetime.datetime(2017, 8, 16, 21, 35, 50), created=datetime.datetime(2016, 9, 15, 10, 22, 56), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008)
# Data(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', employer='Bayer-Kunze', department='Support', employee_id='86-6996270', last_updated=datetime.datetime(2017, 10, 2, 6, 22, 27), created=datetime.datetime(2016, 10, 16, 12, 16, 53), vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988)
# Data(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', employer='Kiehn, Hansen and Will', department='Support', employee_id='94-8005696', last_updated=datetime.datetime(2017, 7, 5, 10, 19, 41), created=datetime.datetime(2016, 7, 23, 3, 16, 13), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997)
# Data(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian', employer='Kling-Howe', department='Research and Development', employee_id='71-7470887', last_updated=datetime.datetime(2017, 11, 3, 0, 36, 20), created=datetime.datetime(2016, 9, 8, 5, 10, 46), vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991)
# Data(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', employer='Quitzon-Morissette', department='Product Management', employee_id='81-5434446', last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46), vehicle_make='Ford', vehicle_model='Mustang', model_year=1998)
# Data(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', employer='Bergstrom-Daniel', department='Marketing', employee_id='31-7381298', last_updated=datetime.datetime(2017, 10, 15, 21, 11, 17), created=datetime.datetime(2016, 11, 17, 18, 52, 56), vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997)
# Data(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', employer='Johnston, Leuschke and Stracke', department='Support', employee_id='96-9321837', last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30), vehicle_make='Scion', vehicle_model='xD', model_year=2011)
# Data(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', employer='Lubowitz-Franecki', department='Product Management', employee_id='68-5287750', last_updated=datetime.datetime(2017, 3, 28, 16, 56, 35), created=datetime.datetime(2016, 6, 3, 5, 38, 20), vehicle_make='Audi', vehicle_model='90', model_year=1991)
# Data(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua', employer='Nienow-Metz', department='Legal', employee_id='88-5601438', last_updated=datetime.datetime(2017, 2, 19, 15, 12, 50), created=datetime.datetime(2016, 10, 24, 14, 3, 4), vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998)
# Data(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', employer='Quitzon, Stiedemann and Breitenberg', department='Services', employee_id='76-1399493', last_updated=datetime.datetime(2017, 7, 1, 13, 56, 28), created=datetime.datetime(2016, 8, 8, 8, 4, 45), vehicle_make='Mercury', vehicle_model='Sable', model_year=2001)
# Data(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', employer='Turner-Connelly', department='Research and Development', employee_id='92-1687621', last_updated=datetime.datetime(2017, 6, 9, 12, 34, 32), created=datetime.datetime(2016, 9, 17, 22, 55, 15), vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990)
# Data(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', employer='Kling, Prosacco and Wisoky', department='Accounting', employee_id='77-0491080', last_updated=datetime.datetime(2017, 12, 26, 5, 29, 23), created=datetime.datetime(2016, 6, 5, 4, 26, 52), vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003)
# Data(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', employer="Von, O'Kon and Runolfsdottir", department='Research and Development', employee_id='34-6414700', last_updated=datetime.datetime(2017, 12, 27, 3, 41, 46), created=datetime.datetime(2016, 6, 30, 2, 48, 10), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985)
# Data(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', employer='McLaughlin-Botsford', department='Business Development', employee_id='60-2450272', last_updated=datetime.datetime(2017, 8, 8, 19, 29, 59), created=datetime.datetime(2016, 9, 9, 19, 38, 18), vehicle_make='BMW', vehicle_model='8 Series', model_year=1995)
# Data(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua', employer='Mann-Stehr', department='Sales', employee_id='82-9383132', last_updated=datetime.datetime(2017, 2, 12, 16, 15, 44), created=datetime.datetime(2016, 6, 21, 4, 10, 57), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Data(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', employer='Smitham-Blick', department='Engineering', employee_id='07-3918459', last_updated=datetime.datetime(2017, 6, 6, 20, 51, 23), created=datetime.datetime(2016, 2, 17, 12, 0, 16), vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990)
# Data(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', employer='Reilly and Sons', department='Product Management', employee_id='00-2155545', last_updated=datetime.datetime(2018, 2, 12, 20, 26, 30), created=datetime.datetime(2016, 4, 15, 16, 42, 18), vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993)
# Data(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', employer='Keeling, Hansen and Mertz', department='Training', employee_id='86-3420084', last_updated=datetime.datetime(2017, 7, 27, 9, 14, 42), created=datetime.datetime(2016, 5, 23, 13, 52, 39), vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009)
# Data(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', employer='Mante Inc', department='Business Development', employee_id='39-8018810', last_updated=datetime.datetime(2017, 3, 18, 6, 5, 59), created=datetime.datetime(2016, 11, 16, 1, 58, 55), vehicle_make='Volvo', vehicle_model='C70', model_year=1998)
# Data(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew', employer='Nicolas Group', department='Support', employee_id='75-2636577', last_updated=datetime.datetime(2017, 1, 19, 20, 59, 49), created=datetime.datetime(2016, 6, 13, 1, 23, 53), vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999)
# Data(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', employer='Sauer, Mann and Kling', department='Accounting', employee_id='89-3029716', last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001)
# Data(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id='29-2776451', last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3), vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007)
# Data(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya', employer='Prosacco LLC', department='Business Development', employee_id='53-6059808', last_updated=datetime.datetime(2017, 1, 23, 2, 41, 20), created=datetime.datetime(2016, 8, 1, 21, 34, 6), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007)
# Data(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian', employer='Mante, Roberts and Miller', department='Research and Development', employee_id='98-1318396', last_updated=datetime.datetime(2017, 2, 13, 7, 16, 31), created=datetime.datetime(2016, 1, 22, 5, 10, 14), vehicle_make='Infiniti', vehicle_model='QX', model_year=2005)
# Data(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', employer='Farrell and Sons', department='Product Management', employee_id='85-3648779', last_updated=datetime.datetime(2017, 6, 23, 12, 59, 20), created=datetime.datetime(2016, 11, 7, 0, 25, 12), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003)
# Data(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', employer='Heathcote-Torp', department='Product Management', employee_id='77-2681193', last_updated=datetime.datetime(2018, 2, 23, 10, 14, 54), created=datetime.datetime(2016, 4, 5, 5, 11, 13), vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006)
# ...
# Data(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', employer='Reinger Inc', department='Engineering', employee_id='80-2005731', last_updated=datetime.datetime(2017, 4, 15, 11, 12, 57), created=datetime.datetime(2016, 6, 22, 23, 23, 9), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007)
# Data(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', employer='Stokes Inc', department='Training', employee_id='12-6635955', last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34), vehicle_make='BMW', vehicle_model='M5', model_year=2007)
# Data(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', employer='Dicki, Green and White', department='Services', employee_id='87-1017676', last_updated=datetime.datetime(2017, 5, 3, 14, 37, 42), created=datetime.datetime(2016, 2, 4, 14, 11, 40), vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002)
# Data(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian', employer='Thiel, Parker and Hilpert', department='Marketing', employee_id='20-2324966', last_updated=datetime.datetime(2017, 2, 4, 13, 53, 10), created=datetime.datetime(2016, 12, 28, 0, 33, 8), vehicle_make='Acura', vehicle_model='ZDX', model_year=2011)
# Data(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama', employer='Heidenreich, Stehr and Huel', department='Sales', employee_id='89-1713880', last_updated=datetime.datetime(2017, 2, 3, 17, 51, 18), created=datetime.datetime(2016, 2, 14, 3, 7, 23), vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004)
# Data(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', employer='Bartoletti Inc', department='Support', employee_id='77-7239839', last_updated=datetime.datetime(2017, 5, 31, 4, 28, 19), created=datetime.datetime(2016, 2, 2, 17, 47, 22), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Data(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', employer='Douglas-Breitenberg', department='Business Development', employee_id='63-6285198', last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20), vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997)
# Data(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', employer='Nitzsche-Walker', department='Engineering', employee_id='50-5681388', last_updated=datetime.datetime(2018, 1, 25, 4, 2, 4), created=datetime.datetime(2016, 10, 31, 14, 12, 16), vehicle_make='Volvo', vehicle_model='S80', model_year=2001)
# Data(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', employer='Crist, Leuschke and Grimes', department='Legal', employee_id='09-8398802', last_updated=datetime.datetime(2017, 10, 31, 17, 48, 23), created=datetime.datetime(2016, 7, 17, 9, 50, 7), vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986)
# Data(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', employer='Emard Inc', department='Business Development', employee_id='49-2589434', last_updated=datetime.datetime(2018, 3, 11, 16, 42, 31), created=datetime.datetime(2016, 11, 4, 18, 34, 52), vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# Data(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', employer='Abshire Inc', department='Research and Development', employee_id='55-8987515', last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007)
# Data(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana', employer='Thompson, Parker and Moen', department='Research and Development', employee_id='46-1484106', last_updated=datetime.datetime(2017, 1, 19, 3, 43, 35), created=datetime.datetime(2016, 6, 24, 16, 43, 15), vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991)
# Data(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', employer='Morissette, Rowe and Muller', department='Engineering', employee_id='73-9912953', last_updated=datetime.datetime(2017, 3, 3, 3, 45, 30), created=datetime.datetime(2016, 6, 21, 17, 1, 53), vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998)
# Data(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id='16-1937114', last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26), vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000)
# Data(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', employer='Glover, Jacobs and Heidenreich', department='Sales', employee_id='72-1577952', last_updated=datetime.datetime(2018, 3, 22, 21, 11, 58), created=datetime.datetime(2016, 4, 27, 3, 27, 17), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Data(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', employer='Cummings-Mertz', department='Sales', employee_id='78-2291834', last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19), vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# Data(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', employer='Wilderman-Grimes', department='Engineering', employee_id='39-6055619', last_updated=datetime.datetime(2017, 7, 23, 1, 30, 5), created=datetime.datetime(2016, 7, 8, 7, 10, 52), vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964)
# Data(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', employer='Schultz-Medhurst', department='Support', employee_id='56-6050344', last_updated=datetime.datetime(2017, 3, 14, 4, 45, 19), created=datetime.datetime(2016, 8, 19, 18, 23, 57), vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993)
# Data(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', employer='Wunsch-Gleason', department='Services', employee_id='28-3015726', last_updated=datetime.datetime(2017, 12, 3, 21, 27, 47), created=datetime.datetime(2016, 6, 12, 12, 36, 44), vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000)
# Data(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', employer='Witting, Schuster and Barton', department='Research and Development', employee_id='54-4161357', last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37), vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998)
# Data(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri', employer='Harber-Legros', department='Training', employee_id='59-9280036', last_updated=datetime.datetime(2017, 1, 13, 19, 50, 26), created=datetime.datetime(2016, 6, 11, 20, 35, 38), vehicle_make='Toyota', vehicle_model='Camry', model_year=2008)
# Data(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', employer='Daugherty, Gislason and Kreiger', department='Training', employee_id='25-5973403', last_updated=datetime.datetime(2018, 2, 4, 17, 29, 28), created=datetime.datetime(2016, 10, 5, 21, 57, 12), vehicle_make='Infiniti', vehicle_model='G', model_year=2004)
# Data(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', employer="O'Connell, Raynor and Veum", department='Sales', employee_id='16-0843654', last_updated=datetime.datetime(2017, 8, 11, 11, 40, 28), created=datetime.datetime(2016, 1, 18, 12, 51), vehicle_make='Subaru', vehicle_model='SVX', model_year=1994)
# Data(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', employer='Schumm Inc', department='Services', employee_id='18-8360445', last_updated=datetime.datetime(2018, 1, 29, 16, 6, 26), created=datetime.datetime(2016, 11, 24, 12, 12, 51), vehicle_make='BMW', vehicle_model='M6', model_year=2009)
# Data(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian', employer='Zulauf Inc', department='Accounting', employee_id='46-7067366', last_updated=datetime.datetime(2017, 2, 10, 19, 26, 8), created=datetime.datetime(2016, 8, 27, 5, 43, 5), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Data(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian', employer='Stanton, Price and Wehner', department='Services', employee_id='16-5769119', last_updated=datetime.datetime(2017, 1, 9, 19, 30, 49), created=datetime.datetime(2016, 3, 18, 22, 13, 6), vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996)
# Data(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id='71-6097002', last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53), vehicle_make='Lexus', vehicle_model='GS', model_year=2013)
# Data(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', employer='Terry and Sons', department='Research and Development', employee_id='06-9390159', last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28), vehicle_make='Audi', vehicle_model='S6', model_year=2011)
# Data(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', employer='Herzog, Stehr and Quitzon', department='Engineering', employee_id='38-5385705', last_updated=datetime.datetime(2018, 3, 6, 16, 54, 20), created=datetime.datetime(2016, 6, 9, 11, 3, 40), vehicle_make='Nissan', vehicle_model='Armada', model_year=2008)
# Data(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', employer='Collier, Hilll and Hagenes', department='Training', employee_id='15-6651242', last_updated=datetime.datetime(2017, 9, 5, 0, 30), created=datetime.datetime(2016, 2, 12, 1, 35, 59), vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991)
# Data(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id='48-3998718', last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16), vehicle_make='Volvo', vehicle_model='S60', model_year=2005)
# Data(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', employer='Heller, Kihn and Bartoletti', department='Research and Development', employee_id='56-9393666', last_updated=datetime.datetime(2018, 1, 6, 9, 34, 59), created=datetime.datetime(2016, 2, 22, 15, 24, 59), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000)
# Data(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', employer='Christiansen LLC', department='Sales', employee_id='66-1175841', last_updated=datetime.datetime(2018, 3, 27, 1, 24, 58), created=datetime.datetime(2016, 6, 14, 2, 41, 25), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991)
# Data(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', employer='Orn Inc', department='Human Resources', employee_id='38-4356300', last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12), vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# Data(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', employer='Flatley, Senger and Bernier', department='Services', employee_id='72-2633200', last_updated=datetime.datetime(2017, 3, 7, 4, 8, 28), created=datetime.datetime(2016, 7, 9, 11, 43, 17), vehicle_make='Kia', vehicle_model='Sedona', model_year=2012)
# Data(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', employer='Hilll, Kunze and Beer', department='Human Resources', employee_id='90-4168298', last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003)
# Data(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', employer='Franecki LLC', department='Services', employee_id='63-7802530', last_updated=datetime.datetime(2017, 5, 13, 5, 52, 27), created=datetime.datetime(2016, 3, 24, 7, 34, 14), vehicle_make='Acura', vehicle_model='TL', model_year=1999)
# Data(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', employer='Reilly-Jakubowski', department='Marketing', employee_id='77-6363112', last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48), vehicle_make='BMW', vehicle_model='X3', model_year=2011)
# Data(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', employer='Bins-Gerhold', department='Sales', employee_id='89-9965641', last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2), vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994)
# Data(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', employer='Olson-Johnson', department='Support', employee_id='36-7761827', last_updated=datetime.datetime(2017, 7, 3, 14, 27, 26), created=datetime.datetime(2016, 11, 23, 23, 34, 17), vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003)
# Data(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', employer='Cronin LLC', department='Services', employee_id='83-8730953', last_updated=datetime.datetime(2017, 7, 31, 2, 26, 57), created=datetime.datetime(2016, 10, 27, 18, 41, 56), vehicle_make='Toyota', vehicle_model='Camry', model_year=2012)
# Data(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', employer='Little-Hansen', department='Business Development', employee_id='45-8154226', last_updated=datetime.datetime(2017, 8, 2, 13, 32, 33), created=datetime.datetime(2016, 7, 27, 12, 47, 5), vehicle_make='Infiniti', vehicle_model='FX', model_year=2006)
# Data(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id='32-7034344', last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999)
# Data(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', employer='Bednar LLC', department='Support', employee_id='16-6342889', last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23), vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)

# %% [markdown]
# ### GOAL - 4

# %%
from collections import namedtuple
from csv import reader
from datetime import datetime

HEADER = []

def generate(file_name: str):
    def create_tuple(iterator):
        header = next(iterator)
        HEADER.append(header)
        return namedtuple('Data', header)

    def convert(row, mode):
        if mode == 'update_status.csv':
            format = '%Y-%m-%dT%H:%M:%SZ'
            row[1], row[2] = datetime.strptime(row[1], format), datetime.strptime(row[2], format)

        elif mode == 'vehicles.csv':
            row[-1] = int(row[-1])

    with open(file_name) as f:
        data = reader(f, lineterminator='\n')
        Data = create_tuple(data)

        for row in data:
            convert(row, file_name)
            yield Data(*row)

def all_data():
    def create_tuple(header):
        values = []

        for head in header:
            for value in head:
                if value not in values:
                    values.append(value)

        return namedtuple('Data', values)

    gen_lst = [generate(file)
               for file in ('personal_info.csv', 'employment.csv', 'update_status.csv', 'vehicles.csv')]
    iter1, iter2, iter3, iter4 = gen_lst
    _ = next(iter1), next(iter2), next(iter3), next(iter4)
    Data = create_tuple(HEADER)

    while True:
        try:
            data1, data2, data3, data4 = next(iter1), next(iter2), next(iter3), next(iter4)
            all_data = data1 + data2[:-1] + data3[1:] + data4[1:]
            yield Data(*all_data)

        except StopIteration:
            break

def filter_data():
    data = all_data()
    return filter(lambda row: row.last_updated >= datetime(2017, 1, 3, 0, 0, 0), data)
    
def make_by_gender():
    def create_tuple(header):
        values = []

        for head in header:
            for value in head:
                if value not in values:
                    values.append(value)

        return namedtuple('Data', values)
    
    gen_lst = [generate(file) for file in ('personal_info.csv', 'vehicles.csv')]
    iter1, iter2 = gen_lst
    _ = next(iter1), next(iter2)
    Data = create_tuple((('ssn', 'first_name', 'last_name', 'gender,language'),
                         ('vehicle_make', 'vehicle_model', 'model_year')))

# %%
for i in filter_data():
    print(i)
# Out:
# Data(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', employer='Nicolas and Sons', department='Sales', employee_id='41-6841359', last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57), vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# Data(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', employer='Connelly Group', department='Research and Development', employee_id='98-7952860', last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7), vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# Data(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', employer='Upton LLC', department='Marketing', employee_id='56-9817552', last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17), vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# Data(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', employer='Zemlak-Olson', department='Business Development', employee_id='46-2886707', last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57), vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)
# Data(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', employer='Kohler, Bradtke and Davis', department='Support', employee_id='80-0975518', last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35), vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# Data(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', employer='Roberts, Torphy and Dach', department='Human Resources', employee_id='77-4895332', last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43), vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# Data(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', employer='Lind-Jast', department='Marketing', employee_id='79-6418731', last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3), vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000)
# Data(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian', employer='Bashirian-Lueilwitz', department='Engineering', employee_id='44-3328799', last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13), vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# Data(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', employer='Windler, Marks and Haley', department='Services', employee_id='54-6271885', last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12), vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992)
# Data(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', employer='Leffler-Hahn', department='Accounting', employee_id='31-5735282', last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Data(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', employer='Lueilwitz LLC', department='Marketing', employee_id='33-9146042', last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5), vehicle_make='Ford', vehicle_model='Mustang', model_year=1990)
# Data(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', employer='Davis Inc', department='Accounting', employee_id='39-0400385', last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17), vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# Data(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch', employer='Kunze LLC', department='Research and Development', employee_id='78-2612900', last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3), vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011)
# Data(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', employer='Mayert, Rice and Schmitt', department='Product Management', employee_id='85-8596488', last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25), vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# Data(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', employer='Pouros LLC', department='Legal', employee_id='14-2589283', last_updated=datetime.datetime(2017, 10, 30, 23, 54, 38), created=datetime.datetime(2016, 6, 4, 5, 18, 3), vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009)
# Data(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', employer='Pfannerstill Group', department='Research and Development', employee_id='43-1532437', last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26), vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009)
# Data(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian', employer='Ryan Group', department='Sales', employee_id='08-8274517', last_updated=datetime.datetime(2017, 11, 21, 14, 25, 11), created=datetime.datetime(2016, 7, 3, 3, 55, 39), vehicle_make='Buick', vehicle_model='Rainier', model_year=2004)
# Data(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', employer='Ritchie-Pagac', department='Business Development', employee_id='38-0095184', last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17), vehicle_make='Scion', vehicle_model='tC', model_year=2008)
# Data(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew', employer='Schmeler and Sons', department='Research and Development', employee_id='62-3275199', last_updated=datetime.datetime(2017, 2, 18, 23, 9, 25), created=datetime.datetime(2016, 2, 2, 15, 41, 42), vehicle_make='Audi', vehicle_model='S6', model_year=2009)
# Data(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', employer='Kerluke-Dibbert', department='Services', employee_id='90-5121197', last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1), vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007)
# Data(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', employer='Hane-Klocko', department='Human Resources', employee_id='27-2946273', last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992)
# Data(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', employer='Ernser LLC', department='Services', employee_id='07-6466085', last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Data(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', employer='Terry LLC', department='Accounting', employee_id='70-4864087', last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005)
# Data(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', employer='Rolfson, Price and Crooks', department='Business Development', employee_id='77-0255816', last_updated=datetime.datetime(2017, 11, 11, 8, 53, 11), created=datetime.datetime(2016, 7, 10, 20, 49), vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997)
# Data(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', employer='Romaguera, Welch and Haley', department='Engineering', employee_id='14-6523887', last_updated=datetime.datetime(2017, 12, 1, 17, 30, 55), created=datetime.datetime(2016, 7, 23, 15, 52, 53), vehicle_make='Acura', vehicle_model='RL', model_year=2003)
# Data(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', employer='Paucek, Huels and Bauch', department='Accounting', employee_id='21-1452824', last_updated=datetime.datetime(2017, 8, 23, 16, 0, 57), created=datetime.datetime(2016, 6, 26, 23, 46, 48), vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002)
# Data(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', employer='Hayes-Trantow', department='Support', employee_id='07-2855255', last_updated=datetime.datetime(2017, 8, 16, 12, 8, 6), created=datetime.datetime(2016, 10, 23, 13, 32, 13), vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# Data(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id='57-1590433', last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5), vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999)
# Data(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', employer='Mueller-Rath', department='Human Resources', employee_id='05-8069298', last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36), vehicle_make='Ford', vehicle_model='Mustang', model_year=1989)
# Data(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian', employer='Schumm, Schumm and Reichert', department='Engineering', employee_id='73-3839744', last_updated=datetime.datetime(2017, 2, 7, 14, 36, 31), created=datetime.datetime(2016, 7, 8, 17, 46, 23), vehicle_make='Lexus', vehicle_model='RX', model_year=2010)
# Data(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', employer='Tromp-Leffler', department='Support', employee_id='02-6267170', last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004)
# Data(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara', employer='Wolf LLC', department='Engineering', employee_id='53-8370994', last_updated=datetime.datetime(2017, 1, 12, 9, 42, 31), created=datetime.datetime(2016, 10, 9, 1, 14, 36), vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008)
# Data(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', employer='Kulas-Corwin', department='Sales', employee_id='78-0632027', last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21), vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# Data(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', employer='MacGyver, Wiegand and Grant', department='Product Management', employee_id='77-4182531', last_updated=datetime.datetime(2017, 9, 10, 6, 24, 19), created=datetime.datetime(2016, 7, 23, 1, 30, 3), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007)
# Data(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian', employer="Kertzmann-O'Hara", department='Sales', employee_id='44-8015165', last_updated=datetime.datetime(2017, 1, 29, 20, 31, 15), created=datetime.datetime(2016, 7, 13, 9, 52, 36), vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006)
# Data(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', employer='Vandervort, Bernier and Morissette', department='Human Resources', employee_id='14-4998615', last_updated=datetime.datetime(2017, 8, 10, 21, 18), created=datetime.datetime(2016, 12, 19, 21, 37, 6), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Data(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', employer='King-Donnelly', department='Training', employee_id='82-0573004', last_updated=datetime.datetime(2017, 8, 31, 16, 42, 23), created=datetime.datetime(2016, 7, 29, 3, 46, 26), vehicle_make='Dodge', vehicle_model='Neon', model_year=1995)
# Data(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', employer='Harris Inc', department='Support', employee_id='53-7535536', last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56), vehicle_make='BMW', vehicle_model='M', model_year=2001)
# Data(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech', employer='Heidenreich, Bergnaum and Smith', department='Training', employee_id='04-7204163', last_updated=datetime.datetime(2017, 1, 3, 20, 33, 45), created=datetime.datetime(2016, 3, 18, 11, 18, 14), vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988)
# Data(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha', employer='Altenwerth-Heidenreich', department='Research and Development', employee_id='58-3628686', last_updated=datetime.datetime(2017, 2, 11, 10, 18, 21), created=datetime.datetime(2016, 12, 12, 5, 1, 34), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993)
# Data(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', employer='Gibson and Sons', department='Sales', employee_id='57-8173633', last_updated=datetime.datetime(2018, 3, 21, 12, 2, 31), created=datetime.datetime(2016, 2, 3, 23, 26, 27), vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012)
# Data(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi', employer='Rodriguez LLC', department='Legal', employee_id='65-7310166', last_updated=datetime.datetime(2017, 1, 19, 7, 33, 37), created=datetime.datetime(2016, 5, 20, 1, 41, 54), vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992)
# Data(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', employer='Donnelly-Crooks', department='Human Resources', employee_id='22-2943669', last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40), vehicle_make='BMW', vehicle_model='M5', model_year=2006)
# Data(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', employer='Hyatt LLC', department='Training', employee_id='96-9647102', last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17), vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004)
# Data(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', employer='Schuster Group', department='Research and Development', employee_id='72-4728604', last_updated=datetime.datetime(2017, 12, 24, 9, 44, 10), created=datetime.datetime(2016, 3, 1, 19, 9, 29), vehicle_make='Infiniti', vehicle_model='G', model_year=2005)
# Data(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', employer='Homenick-Beer', department='Product Management', employee_id='01-9334133', last_updated=datetime.datetime(2017, 4, 17, 16, 30, 2), created=datetime.datetime(2016, 12, 17, 7, 7, 47), vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992)
# Data(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', employer='VonRueden-Torphy', department='Business Development', employee_id='10-6636122', last_updated=datetime.datetime(2018, 3, 4, 8, 14, 31), created=datetime.datetime(2016, 9, 24, 1, 52, 46), vehicle_make='Lexus', vehicle_model='RX', model_year=2003)
# Data(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese', employer='Mohr, Harvey and Mitchell', department='Legal', employee_id='64-7550101', last_updated=datetime.datetime(2017, 2, 24, 15, 47, 36), created=datetime.datetime(2016, 1, 4, 9, 37, 53), vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004)
# Data(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian', employer='Keeling-Schroeder', department='Engineering', employee_id='82-2479019', last_updated=datetime.datetime(2017, 2, 16, 21, 23, 10), created=datetime.datetime(2016, 5, 24, 4, 10, 50), vehicle_make='Ford', vehicle_model='Escort', model_year=1997)
# Data(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', employer='Gusikowski-Block', department='Legal', employee_id='41-1454732', last_updated=datetime.datetime(2017, 8, 19, 16, 22, 52), created=datetime.datetime(2016, 9, 10, 21, 9, 28), vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990)
# Data(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', employer='Pollich-Heathcote', department='Product Management', employee_id='12-2844710', last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20), vehicle_make='Volvo', vehicle_model='V70', model_year=2002)
# Data(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', employer='Bogisich Inc', department='Human Resources', employee_id='34-7172919', last_updated=datetime.datetime(2017, 9, 21, 23, 4, 48), created=datetime.datetime(2016, 1, 27, 9, 2, 26), vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# Data(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori', employer='Gutkowski Inc', department='Engineering', employee_id='83-4836768', last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22), vehicle_make='Volvo', vehicle_model='XC90', model_year=2009)
# Data(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', employer='Greenholt LLC', department='Sales', employee_id='84-5391800', last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37), vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000)
# Data(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', employer='Hartmann Inc', department='Support', employee_id='26-7276512', last_updated=datetime.datetime(2018, 1, 24, 20, 0, 4), created=datetime.datetime(2016, 12, 20, 0, 43, 43), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Data(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', employer='Zboncak-Gulgowski', department='Marketing', employee_id='05-0368584', last_updated=datetime.datetime(2017, 7, 16, 15, 12, 37), created=datetime.datetime(2016, 7, 30, 13, 28, 38), vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999)
# Data(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', employer='Altenwerth-Emard', department='Marketing', employee_id='30-5847411', last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005)
# Data(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', employer='Cronin Inc', department='Business Development', employee_id='08-3106397', last_updated=datetime.datetime(2017, 7, 21, 18, 54, 47), created=datetime.datetime(2016, 2, 9, 6, 10, 21), vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# Data(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese', employer='Murray, Wolff and Little', department='Business Development', employee_id='29-3578815', last_updated=datetime.datetime(2017, 1, 18, 6, 37, 31), created=datetime.datetime(2016, 4, 25, 21, 45), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Data(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', employer='Dibbert LLC', department='Support', employee_id='09-9620598', last_updated=datetime.datetime(2018, 2, 20, 12, 47, 43), created=datetime.datetime(2016, 10, 3, 5, 18, 6), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Data(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', employer='Tromp Inc', department='Research and Development', employee_id='06-3360383', last_updated=datetime.datetime(2017, 6, 10, 6, 21, 46), created=datetime.datetime(2016, 9, 23, 15, 35, 52), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993)
# Data(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', employer='Kub, Koch and Ratke', department='Marketing', employee_id='72-7830449', last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988)
# Data(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', employer='Greenholt-Gusikowski', department='Engineering', employee_id='16-6006875', last_updated=datetime.datetime(2018, 2, 9, 4, 41, 58), created=datetime.datetime(2016, 5, 31, 23, 38, 59), vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995)
# Data(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', employer='Tremblay, Jacobs and Swift', department='Training', employee_id='46-1648855', last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36), vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996)
# Data(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', employer='Bashirian-Moen', department='Training', employee_id='51-9115041', last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52), vehicle_make='Ford', vehicle_model='Explorer', model_year=2005)
# Data(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', employer='Hudson-Gerhold', department='Human Resources', employee_id='62-2244500', last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29), vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992)
# Data(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', employer='Balistreri Inc', department='Sales', employee_id='92-8183627', last_updated=datetime.datetime(2017, 8, 31, 2, 41, 41), created=datetime.datetime(2016, 10, 21, 12, 17, 57), vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992)
# Data(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', employer='Eichmann, Quigley and Macejkovic', department='Business Development', employee_id='48-8059597', last_updated=datetime.datetime(2017, 9, 2, 5, 13, 32), created=datetime.datetime(2016, 2, 23, 16, 20, 59), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995)
# Data(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', employer='Bosco-Kunde', department='Services', employee_id='55-1726090', last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50), vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000)
# Data(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', employer='Ratke-Raynor', department='Legal', employee_id='60-6687797', last_updated=datetime.datetime(2017, 6, 4, 1, 39, 16), created=datetime.datetime(2016, 4, 23, 14, 7, 49), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Data(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', employer='Bergstrom-Boyle', department='Marketing', employee_id='72-3121170', last_updated=datetime.datetime(2018, 2, 8, 11, 16, 12), created=datetime.datetime(2016, 10, 19, 8, 22, 59), vehicle_make='Ford', vehicle_model='Probe', model_year=1996)
# Data(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy', employer='McLaughlin-Rohan', department='Legal', employee_id='47-1922172', last_updated=datetime.datetime(2017, 2, 13, 21, 31, 15), created=datetime.datetime(2016, 4, 28, 8, 28, 43), vehicle_make='Ford', vehicle_model='F250', model_year=1999)
# Data(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id='93-3103060', last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10), vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# Data(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', employer='Little, Hagenes and McKenzie', department='Training', employee_id='75-9906937', last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001)
# Data(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French', employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id='95-5604381', last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39), vehicle_make='Ford', vehicle_model='Taurus', model_year=1998)
# Data(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', employer='Gorczany LLC', department='Training', employee_id='62-8983936', last_updated=datetime.datetime(2017, 4, 19, 22, 8, 24), created=datetime.datetime(2016, 1, 29, 12, 43, 45), vehicle_make='Nissan', vehicle_model='Armada', model_year=2005)
# Data(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', employer='Little, Powlowski and Witting', department='Business Development', employee_id='42-4459617', last_updated=datetime.datetime(2017, 9, 10, 22, 58, 31), created=datetime.datetime(2016, 10, 20, 19, 49, 24), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011)
# Data(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', employer='King LLC', department='Research and Development', employee_id='39-4026042', last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32), vehicle_make='Acura', vehicle_model='TL', model_year=2005)
# Data(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', employer='Konopelski-Vandervort', department='Legal', employee_id='87-8332368', last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29), vehicle_make='Audi', vehicle_model='Q7', model_year=2007)
# Data(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', employer='Reichel Group', department='Training', employee_id='10-5605387', last_updated=datetime.datetime(2017, 3, 24, 8, 58, 33), created=datetime.datetime(2016, 9, 15, 16, 11, 12), vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005)
# Data(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', employer='Gerhold-Marquardt', department='Research and Development', employee_id='25-6013938', last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2), vehicle_make='BMW', vehicle_model='Z3', model_year=1996)
# Data(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', employer='Greenholt-Hermiston', department='Business Development', employee_id='66-9841280', last_updated=datetime.datetime(2017, 7, 3, 6, 26, 41), created=datetime.datetime(2016, 6, 9, 5, 30, 33), vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999)
# Data(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id='83-2548521', last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55), vehicle_make='Ford', vehicle_model='Mustang', model_year=1995)
# Data(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', employer='Roberts Group', department='Product Management', employee_id='07-6620387', last_updated=datetime.datetime(2017, 9, 6, 16, 56, 6), created=datetime.datetime(2016, 10, 23, 1, 47, 51), vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998)
# Data(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', employer='Olson-Lynch', department='Business Development', employee_id='50-7113609', last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33), vehicle_make='Honda', vehicle_model='Civic', model_year=2012)
# Data(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', employer='Quitzon, Rempel and Hane', department='Business Development', employee_id='03-4767523', last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001)
# Data(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', employer='Carroll, Konopelski and Wunsch', department='Research and Development', employee_id='43-4797129', last_updated=datetime.datetime(2017, 8, 14, 16, 48, 43), created=datetime.datetime(2016, 7, 2, 8, 33, 48), vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008)
# Data(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', employer='Howell LLC', department='Business Development', employee_id='70-2399476', last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1), vehicle_make='GMC', vehicle_model='3500', model_year=1998)
# Data(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', employer='Johnson Inc', department='Services', employee_id='34-7741883', last_updated=datetime.datetime(2018, 1, 4, 21, 50, 39), created=datetime.datetime(2016, 1, 29, 15, 31, 40), vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989)
# Data(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', employer='Corwin and Sons', department='Legal', employee_id='15-8160997', last_updated=datetime.datetime(2017, 6, 10, 3, 48, 51), created=datetime.datetime(2016, 9, 27, 15, 4, 24), vehicle_make='Toyota', vehicle_model='MR2', model_year=1993)
# Data(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara', employer='Zemlak LLC', department='Research and Development', employee_id='86-8667896', last_updated=datetime.datetime(2017, 2, 11, 14, 12, 16), created=datetime.datetime(2016, 9, 19, 20, 5, 7), vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012)
# Data(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', employer='Toy-Jakubowski', department='Engineering', employee_id='17-8085199', last_updated=datetime.datetime(2017, 7, 17, 2, 59, 15), created=datetime.datetime(2016, 4, 30, 9, 17, 39), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964)
# Data(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', employer='Murphy, Windler and Bartoletti', department='Legal', employee_id='02-6976472', last_updated=datetime.datetime(2017, 3, 5, 0, 46, 26), created=datetime.datetime(2016, 6, 15, 5, 37, 27), vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010)
# Data(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', employer='Batz Inc', department='Support', employee_id='49-2738721', last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37), vehicle_make='Ford', vehicle_model='Mustang', model_year=1985)
# Data(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', employer='Jast and Sons', department='Services', employee_id='38-6141294', last_updated=datetime.datetime(2018, 3, 2, 23, 30, 36), created=datetime.datetime(2016, 5, 12, 16, 1, 48), vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011)
# Data(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French', employer='Roberts LLC', department='Research and Development', employee_id='91-2028080', last_updated=datetime.datetime(2017, 10, 11, 13, 32, 41), created=datetime.datetime(2016, 9, 10, 9, 18, 50), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Data(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian', employer='Schultz, Price and Walsh', department='Business Development', employee_id='69-6328477', last_updated=datetime.datetime(2017, 1, 25, 2, 11, 6), created=datetime.datetime(2016, 7, 24, 12, 57, 57), vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969)
# Data(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', employer='Zulauf, Hudson and Wisozk', department='Research and Development', employee_id='39-1896194', last_updated=datetime.datetime(2018, 3, 3, 15, 18, 26), created=datetime.datetime(2016, 10, 26, 15, 24, 37), vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# Data(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', employer='Bode-Zulauf', department='Marketing', employee_id='42-0021775', last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59), vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988)
# Data(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz', employer='Windler Group', department='Legal', employee_id='16-2190623', last_updated=datetime.datetime(2017, 1, 25, 11, 34, 25), created=datetime.datetime(2016, 5, 14, 4, 55, 35), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972)
# Data(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati', employer='Jast-Quitzon', department='Human Resources', employee_id='67-5707294', last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25), vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994)
# Data(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian', employer='Green-Waelchi', department='Engineering', employee_id='29-7065788', last_updated=datetime.datetime(2017, 9, 30, 14, 38, 36), created=datetime.datetime(2016, 8, 1, 11, 19, 25), vehicle_make='Ford', vehicle_model='Taurus', model_year=1991)
# Data(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai', employer='Brown Group', department='Accounting', employee_id='91-0435820', last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42), vehicle_make='Toyota', vehicle_model='Celica', model_year=1995)
# Data(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', employer='MacGyver-Hartmann', department='Accounting', employee_id='77-4207310', last_updated=datetime.datetime(2017, 4, 1, 20, 14, 53), created=datetime.datetime(2016, 12, 3, 15, 8, 4), vehicle_make='Jeep', vehicle_model='Commander', model_year=2007)
# Data(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', employer='McGlynn LLC', department='Support', employee_id='35-4393230', last_updated=datetime.datetime(2017, 3, 23, 1, 30, 12), created=datetime.datetime(2016, 3, 6, 13, 15, 20), vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013)
# Data(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', employer='Little, Herzog and Mertz', department='Legal', employee_id='45-9164509', last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19), vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995)
# Data(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', employer='Kertzmann-Reichel', department='Research and Development', employee_id='67-0581933', last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49), vehicle_make='GMC', vehicle_model='Canyon', model_year=2004)
# Data(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', employer='Douglas, Funk and Schowalter', department='Services', employee_id='77-2512148', last_updated=datetime.datetime(2017, 8, 16, 21, 35, 50), created=datetime.datetime(2016, 9, 15, 10, 22, 56), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008)
# Data(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', employer='Bayer-Kunze', department='Support', employee_id='86-6996270', last_updated=datetime.datetime(2017, 10, 2, 6, 22, 27), created=datetime.datetime(2016, 10, 16, 12, 16, 53), vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988)
# Data(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', employer='Kiehn, Hansen and Will', department='Support', employee_id='94-8005696', last_updated=datetime.datetime(2017, 7, 5, 10, 19, 41), created=datetime.datetime(2016, 7, 23, 3, 16, 13), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997)
# Data(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian', employer='Kling-Howe', department='Research and Development', employee_id='71-7470887', last_updated=datetime.datetime(2017, 11, 3, 0, 36, 20), created=datetime.datetime(2016, 9, 8, 5, 10, 46), vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991)
# Data(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', employer='Quitzon-Morissette', department='Product Management', employee_id='81-5434446', last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46), vehicle_make='Ford', vehicle_model='Mustang', model_year=1998)
# Data(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', employer='Bergstrom-Daniel', department='Marketing', employee_id='31-7381298', last_updated=datetime.datetime(2017, 10, 15, 21, 11, 17), created=datetime.datetime(2016, 11, 17, 18, 52, 56), vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997)
# Data(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', employer='Johnston, Leuschke and Stracke', department='Support', employee_id='96-9321837', last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30), vehicle_make='Scion', vehicle_model='xD', model_year=2011)
# Data(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', employer='Lubowitz-Franecki', department='Product Management', employee_id='68-5287750', last_updated=datetime.datetime(2017, 3, 28, 16, 56, 35), created=datetime.datetime(2016, 6, 3, 5, 38, 20), vehicle_make='Audi', vehicle_model='90', model_year=1991)
# Data(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua', employer='Nienow-Metz', department='Legal', employee_id='88-5601438', last_updated=datetime.datetime(2017, 2, 19, 15, 12, 50), created=datetime.datetime(2016, 10, 24, 14, 3, 4), vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998)
# Data(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', employer='Quitzon, Stiedemann and Breitenberg', department='Services', employee_id='76-1399493', last_updated=datetime.datetime(2017, 7, 1, 13, 56, 28), created=datetime.datetime(2016, 8, 8, 8, 4, 45), vehicle_make='Mercury', vehicle_model='Sable', model_year=2001)
# Data(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', employer='Turner-Connelly', department='Research and Development', employee_id='92-1687621', last_updated=datetime.datetime(2017, 6, 9, 12, 34, 32), created=datetime.datetime(2016, 9, 17, 22, 55, 15), vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990)
# Data(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', employer='Kling, Prosacco and Wisoky', department='Accounting', employee_id='77-0491080', last_updated=datetime.datetime(2017, 12, 26, 5, 29, 23), created=datetime.datetime(2016, 6, 5, 4, 26, 52), vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003)
# Data(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', employer="Von, O'Kon and Runolfsdottir", department='Research and Development', employee_id='34-6414700', last_updated=datetime.datetime(2017, 12, 27, 3, 41, 46), created=datetime.datetime(2016, 6, 30, 2, 48, 10), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985)
# Data(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', employer='McLaughlin-Botsford', department='Business Development', employee_id='60-2450272', last_updated=datetime.datetime(2017, 8, 8, 19, 29, 59), created=datetime.datetime(2016, 9, 9, 19, 38, 18), vehicle_make='BMW', vehicle_model='8 Series', model_year=1995)
# Data(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua', employer='Mann-Stehr', department='Sales', employee_id='82-9383132', last_updated=datetime.datetime(2017, 2, 12, 16, 15, 44), created=datetime.datetime(2016, 6, 21, 4, 10, 57), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Data(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', employer='Smitham-Blick', department='Engineering', employee_id='07-3918459', last_updated=datetime.datetime(2017, 6, 6, 20, 51, 23), created=datetime.datetime(2016, 2, 17, 12, 0, 16), vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990)
# Data(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', employer='Reilly and Sons', department='Product Management', employee_id='00-2155545', last_updated=datetime.datetime(2018, 2, 12, 20, 26, 30), created=datetime.datetime(2016, 4, 15, 16, 42, 18), vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993)
# Data(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', employer='Keeling, Hansen and Mertz', department='Training', employee_id='86-3420084', last_updated=datetime.datetime(2017, 7, 27, 9, 14, 42), created=datetime.datetime(2016, 5, 23, 13, 52, 39), vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009)
# Data(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', employer='Mante Inc', department='Business Development', employee_id='39-8018810', last_updated=datetime.datetime(2017, 3, 18, 6, 5, 59), created=datetime.datetime(2016, 11, 16, 1, 58, 55), vehicle_make='Volvo', vehicle_model='C70', model_year=1998)
# Data(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew', employer='Nicolas Group', department='Support', employee_id='75-2636577', last_updated=datetime.datetime(2017, 1, 19, 20, 59, 49), created=datetime.datetime(2016, 6, 13, 1, 23, 53), vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999)
# Data(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', employer='Sauer, Mann and Kling', department='Accounting', employee_id='89-3029716', last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001)
# Data(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id='29-2776451', last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3), vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007)
# Data(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya', employer='Prosacco LLC', department='Business Development', employee_id='53-6059808', last_updated=datetime.datetime(2017, 1, 23, 2, 41, 20), created=datetime.datetime(2016, 8, 1, 21, 34, 6), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007)
# Data(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian', employer='Mante, Roberts and Miller', department='Research and Development', employee_id='98-1318396', last_updated=datetime.datetime(2017, 2, 13, 7, 16, 31), created=datetime.datetime(2016, 1, 22, 5, 10, 14), vehicle_make='Infiniti', vehicle_model='QX', model_year=2005)
# Data(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', employer='Farrell and Sons', department='Product Management', employee_id='85-3648779', last_updated=datetime.datetime(2017, 6, 23, 12, 59, 20), created=datetime.datetime(2016, 11, 7, 0, 25, 12), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003)
# Data(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', employer='Heathcote-Torp', department='Product Management', employee_id='77-2681193', last_updated=datetime.datetime(2018, 2, 23, 10, 14, 54), created=datetime.datetime(2016, 4, 5, 5, 11, 13), vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006)
# ...
# Data(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', employer='Reinger Inc', department='Engineering', employee_id='80-2005731', last_updated=datetime.datetime(2017, 4, 15, 11, 12, 57), created=datetime.datetime(2016, 6, 22, 23, 23, 9), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007)
# Data(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', employer='Stokes Inc', department='Training', employee_id='12-6635955', last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34), vehicle_make='BMW', vehicle_model='M5', model_year=2007)
# Data(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', employer='Dicki, Green and White', department='Services', employee_id='87-1017676', last_updated=datetime.datetime(2017, 5, 3, 14, 37, 42), created=datetime.datetime(2016, 2, 4, 14, 11, 40), vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002)
# Data(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian', employer='Thiel, Parker and Hilpert', department='Marketing', employee_id='20-2324966', last_updated=datetime.datetime(2017, 2, 4, 13, 53, 10), created=datetime.datetime(2016, 12, 28, 0, 33, 8), vehicle_make='Acura', vehicle_model='ZDX', model_year=2011)
# Data(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama', employer='Heidenreich, Stehr and Huel', department='Sales', employee_id='89-1713880', last_updated=datetime.datetime(2017, 2, 3, 17, 51, 18), created=datetime.datetime(2016, 2, 14, 3, 7, 23), vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004)
# Data(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', employer='Bartoletti Inc', department='Support', employee_id='77-7239839', last_updated=datetime.datetime(2017, 5, 31, 4, 28, 19), created=datetime.datetime(2016, 2, 2, 17, 47, 22), vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Data(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', employer='Douglas-Breitenberg', department='Business Development', employee_id='63-6285198', last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20), vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997)
# Data(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', employer='Nitzsche-Walker', department='Engineering', employee_id='50-5681388', last_updated=datetime.datetime(2018, 1, 25, 4, 2, 4), created=datetime.datetime(2016, 10, 31, 14, 12, 16), vehicle_make='Volvo', vehicle_model='S80', model_year=2001)
# Data(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', employer='Crist, Leuschke and Grimes', department='Legal', employee_id='09-8398802', last_updated=datetime.datetime(2017, 10, 31, 17, 48, 23), created=datetime.datetime(2016, 7, 17, 9, 50, 7), vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986)
# Data(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', employer='Emard Inc', department='Business Development', employee_id='49-2589434', last_updated=datetime.datetime(2018, 3, 11, 16, 42, 31), created=datetime.datetime(2016, 11, 4, 18, 34, 52), vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# Data(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', employer='Abshire Inc', department='Research and Development', employee_id='55-8987515', last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007)
# Data(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana', employer='Thompson, Parker and Moen', department='Research and Development', employee_id='46-1484106', last_updated=datetime.datetime(2017, 1, 19, 3, 43, 35), created=datetime.datetime(2016, 6, 24, 16, 43, 15), vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991)
# Data(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', employer='Morissette, Rowe and Muller', department='Engineering', employee_id='73-9912953', last_updated=datetime.datetime(2017, 3, 3, 3, 45, 30), created=datetime.datetime(2016, 6, 21, 17, 1, 53), vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998)
# Data(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id='16-1937114', last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26), vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000)
# Data(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', employer='Glover, Jacobs and Heidenreich', department='Sales', employee_id='72-1577952', last_updated=datetime.datetime(2018, 3, 22, 21, 11, 58), created=datetime.datetime(2016, 4, 27, 3, 27, 17), vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Data(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', employer='Cummings-Mertz', department='Sales', employee_id='78-2291834', last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19), vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# Data(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', employer='Wilderman-Grimes', department='Engineering', employee_id='39-6055619', last_updated=datetime.datetime(2017, 7, 23, 1, 30, 5), created=datetime.datetime(2016, 7, 8, 7, 10, 52), vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964)
# Data(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', employer='Schultz-Medhurst', department='Support', employee_id='56-6050344', last_updated=datetime.datetime(2017, 3, 14, 4, 45, 19), created=datetime.datetime(2016, 8, 19, 18, 23, 57), vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993)
# Data(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', employer='Wunsch-Gleason', department='Services', employee_id='28-3015726', last_updated=datetime.datetime(2017, 12, 3, 21, 27, 47), created=datetime.datetime(2016, 6, 12, 12, 36, 44), vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000)
# Data(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', employer='Witting, Schuster and Barton', department='Research and Development', employee_id='54-4161357', last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37), vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998)
# Data(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri', employer='Harber-Legros', department='Training', employee_id='59-9280036', last_updated=datetime.datetime(2017, 1, 13, 19, 50, 26), created=datetime.datetime(2016, 6, 11, 20, 35, 38), vehicle_make='Toyota', vehicle_model='Camry', model_year=2008)
# Data(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', employer='Daugherty, Gislason and Kreiger', department='Training', employee_id='25-5973403', last_updated=datetime.datetime(2018, 2, 4, 17, 29, 28), created=datetime.datetime(2016, 10, 5, 21, 57, 12), vehicle_make='Infiniti', vehicle_model='G', model_year=2004)
# Data(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', employer="O'Connell, Raynor and Veum", department='Sales', employee_id='16-0843654', last_updated=datetime.datetime(2017, 8, 11, 11, 40, 28), created=datetime.datetime(2016, 1, 18, 12, 51), vehicle_make='Subaru', vehicle_model='SVX', model_year=1994)
# Data(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', employer='Schumm Inc', department='Services', employee_id='18-8360445', last_updated=datetime.datetime(2018, 1, 29, 16, 6, 26), created=datetime.datetime(2016, 11, 24, 12, 12, 51), vehicle_make='BMW', vehicle_model='M6', model_year=2009)
# Data(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian', employer='Zulauf Inc', department='Accounting', employee_id='46-7067366', last_updated=datetime.datetime(2017, 2, 10, 19, 26, 8), created=datetime.datetime(2016, 8, 27, 5, 43, 5), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Data(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian', employer='Stanton, Price and Wehner', department='Services', employee_id='16-5769119', last_updated=datetime.datetime(2017, 1, 9, 19, 30, 49), created=datetime.datetime(2016, 3, 18, 22, 13, 6), vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996)
# Data(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id='71-6097002', last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53), vehicle_make='Lexus', vehicle_model='GS', model_year=2013)
# Data(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', employer='Terry and Sons', department='Research and Development', employee_id='06-9390159', last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28), vehicle_make='Audi', vehicle_model='S6', model_year=2011)
# Data(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', employer='Herzog, Stehr and Quitzon', department='Engineering', employee_id='38-5385705', last_updated=datetime.datetime(2018, 3, 6, 16, 54, 20), created=datetime.datetime(2016, 6, 9, 11, 3, 40), vehicle_make='Nissan', vehicle_model='Armada', model_year=2008)
# Data(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', employer='Collier, Hilll and Hagenes', department='Training', employee_id='15-6651242', last_updated=datetime.datetime(2017, 9, 5, 0, 30), created=datetime.datetime(2016, 2, 12, 1, 35, 59), vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991)
# Data(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id='48-3998718', last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16), vehicle_make='Volvo', vehicle_model='S60', model_year=2005)
# Data(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', employer='Heller, Kihn and Bartoletti', department='Research and Development', employee_id='56-9393666', last_updated=datetime.datetime(2018, 1, 6, 9, 34, 59), created=datetime.datetime(2016, 2, 22, 15, 24, 59), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000)
# Data(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', employer='Christiansen LLC', department='Sales', employee_id='66-1175841', last_updated=datetime.datetime(2018, 3, 27, 1, 24, 58), created=datetime.datetime(2016, 6, 14, 2, 41, 25), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991)
# Data(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', employer='Orn Inc', department='Human Resources', employee_id='38-4356300', last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12), vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# Data(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', employer='Flatley, Senger and Bernier', department='Services', employee_id='72-2633200', last_updated=datetime.datetime(2017, 3, 7, 4, 8, 28), created=datetime.datetime(2016, 7, 9, 11, 43, 17), vehicle_make='Kia', vehicle_model='Sedona', model_year=2012)
# Data(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', employer='Hilll, Kunze and Beer', department='Human Resources', employee_id='90-4168298', last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003)
# Data(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', employer='Franecki LLC', department='Services', employee_id='63-7802530', last_updated=datetime.datetime(2017, 5, 13, 5, 52, 27), created=datetime.datetime(2016, 3, 24, 7, 34, 14), vehicle_make='Acura', vehicle_model='TL', model_year=1999)
# Data(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', employer='Reilly-Jakubowski', department='Marketing', employee_id='77-6363112', last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48), vehicle_make='BMW', vehicle_model='X3', model_year=2011)
# Data(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', employer='Bins-Gerhold', department='Sales', employee_id='89-9965641', last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2), vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994)
# Data(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', employer='Olson-Johnson', department='Support', employee_id='36-7761827', last_updated=datetime.datetime(2017, 7, 3, 14, 27, 26), created=datetime.datetime(2016, 11, 23, 23, 34, 17), vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003)
# Data(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', employer='Cronin LLC', department='Services', employee_id='83-8730953', last_updated=datetime.datetime(2017, 7, 31, 2, 26, 57), created=datetime.datetime(2016, 10, 27, 18, 41, 56), vehicle_make='Toyota', vehicle_model='Camry', model_year=2012)
# Data(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', employer='Little-Hansen', department='Business Development', employee_id='45-8154226', last_updated=datetime.datetime(2017, 8, 2, 13, 32, 33), created=datetime.datetime(2016, 7, 27, 12, 47, 5), vehicle_make='Infiniti', vehicle_model='FX', model_year=2006)
# Data(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id='32-7034344', last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999)
# Data(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', employer='Bednar LLC', department='Support', employee_id='16-6342889', last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23), vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)
